# %%
# # Audio Emotion Classification
# This notebook demonstrates how to use the AudioEmotionClassifier to analyze emotions in audio files.

# %% [Cell 1] Import the classifier
import os
from audio_emotion_classifier import AudioEmotionClassifier

# %%
# Initialize the classifier
classifier = AudioEmotionClassifier(model_path='best_emotion_model_192x192.h5')
# Out:
# ✓ Model loaded successfully from best_emotion_model_192x192.h5

# %%
import os
import sounddevice as sd
import numpy as np
import wave
from pydub import AudioSegment

# 🔹 Gravar áudio do microfone e salvar como WAV
def record_audio(filename="output.wav", duration=6, samplerate=44100):
    print("🎙️ Gravando... Fale algo!")
    audio_data = sd.rec(int(duration * samplerate), samplerate=samplerate, channels=1, dtype=np.int16)
    sd.wait()
    
    with wave.open(filename, "wb") as wf:
        wf.setnchannels(1)
        wf.setsampwidth(2)
        wf.setframerate(samplerate)
        wf.writeframes(audio_data.tobytes())
    
    print(f"✅ Áudio salvo como {filename}")
    return filename

# 🔹 Executar o processo completo
if __name__ == "__main__":
    wav_file = record_audio(duration=6)  # Grava por 5 segundos
# Out:
# c:\Users\eel20\anaconda3\envs\nlp_proj\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# 🎙️ Gravando... Fale algo!
# ✅ Áudio salvo como output.wav

# %%
# Process another file directly
result2 = classifier.predict(audio_path=r"output.wav")
# Note: This does everything in one step - loads, displays, creates spectrogram, and predicts


# Final Project
def voice_to_text_prediction():
    """Graba audio y transcrribe a texto usando Whisper"""
    import sounddevice as sd
    import numpy as np
    import wave
    from pydub import AudioSegment
    import whisper


    def transcribe_audio(audio_path):
        print("📝 Transcrevendo o áudio...")
        model = whisper.load_model("small")
        result = model.transcribe(audio_path, language="en")
        return result["text"]

    transcribed_text = transcribe_audio(result2)
    return transcribed_text

# Call the function and print the result
transcribed_text = voice_to_text_prediction()
print(transcribed_text)
# Out:
# ✓ Loaded audio: output.wav (6.00 seconds)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ✓ Saved spectrogram to output_mel.png
# 🎭 Predicted Emotion: disgust (56.10% confidence)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 26
#      23     return transcribed_text
#      25 # Call the function and print the result
# ---> 26 transcribed_text = voice_to_text_prediction()
#      27 print(transcribed_text)
#
# Cell In[4], line 13, in voice_to_text_prediction()
#      11 import wave
#      12 from pydub import AudioSegment
# ---> 13 import whisper
#      16 def transcribe_audio(audio_path):
#      17     print("📝 Transcrevendo o áudio...")
#
# ...
