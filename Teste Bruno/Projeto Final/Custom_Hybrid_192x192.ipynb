# %%
import os
import glob
import numpy as np
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, RNN, LSTMCell, BatchNormalization, Conv2D, MaxPooling2D, Flatten, Reshape
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, classification_report

# %%
def load_data(dataset_path, img_size=(192, 192)):
    """
    Loads precomputed mel-spectrogram images and extracts labels from folder names.
    Resizes images to 192x192 for higher resolution.
    """
    X = []
    y = []
    class_names = sorted(os.listdir(dataset_path))  # Get emotion categories
    
    for label in class_names:
        class_path = os.path.join(dataset_path, label)
        if not os.path.isdir(class_path):
            continue
        
        files = glob.glob(os.path.join(class_path, '*.png'))
        print(f"Found {len(files)} images for class '{label}'.")
        
        for file in files:
            img = cv2.imread(file, cv2.IMREAD_GRAYSCALE)  # Load in grayscale
            img = cv2.resize(img, img_size)  # Resize to higher resolution
            X.append(img)
            y.append(label)
    
    X = np.array(X, dtype=np.float32) / 255.0  # Normalize pixel values
    y = np.array(y)
    return X, y, class_names

# %%
def augment_data(X, y, augmentation_factor=0.3):
    """Apply simple data augmentation to improve model generalization"""
    aug_X = []
    aug_y = []
    
    for i in range(len(X)):
        # Original sample
        aug_X.append(X[i])
        aug_y.append(y[i])
        
        # Apply time stretching (horizontal scaling)
        if np.random.random() < augmentation_factor:
            stretched = cv2.resize(X[i], (int(X[i].shape[1] * 1.1), X[i].shape[0]))
            stretched = cv2.resize(stretched, (X[i].shape[1], X[i].shape[0]))
            aug_X.append(stretched)
            aug_y.append(y[i])
        
        # Apply frequency masking (random horizontal lines masked)
        if np.random.random() < augmentation_factor:
            masked = X[i].copy()
            num_masks = np.random.randint(1, 4)
            for _ in range(num_masks):
                freq_width = np.random.randint(5, 20)  # Wider masks for larger image
                freq_start = np.random.randint(0, X[i].shape[0] - freq_width)
                masked[freq_start:freq_start+freq_width, :] = 0
            aug_X.append(masked)
            aug_y.append(y[i])
    
    return np.array(aug_X), np.array(aug_y)

# %%
def preprocess_labels(y):
    """Encodes string labels into numerical one-hot vectors."""
    le = LabelEncoder()
    y_encoded = le.fit_transform(y)
    y_onehot = to_categorical(y_encoded)
    return y_onehot, le

# %%
def build_hybrid_model_192(input_shape, num_classes):
    """
    Builds a hybrid CNN-LSTM model for 192x192 inputs.
    Adjusted architecture to handle larger input dimensions.
    """
    model = Sequential()
    
    # First, add CNN layers to extract spatial features
    model.add(Reshape((input_shape[0], input_shape[1], 1), input_shape=input_shape))
    
    # First conv block
    model.add(Conv2D(32, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(Conv2D(32, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))  # Output: 96x96x32
    
    # Second conv block
    model.add(Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))  # Output: 48x48x64
    
    # Third conv block - added for larger input size
    model.add(Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))  # Output: 24x24x128
    
    # Reshape for LSTM - treat rows as time steps
    # After 3 MaxPooling layers, we have 24x24x128, reshape to 24 timesteps with 24*128 features
    model.add(Reshape((24, 24*128)))
    
    # LSTM layers for temporal features
    model.add(RNN(LSTMCell(256), return_sequences=True))  # Increased units for larger input
    model.add(Dropout(0.3))
    model.add(RNN(LSTMCell(128)))  # Increased units
    model.add(Dropout(0.3))
    
    # Classification layers
    model.add(Dense(128, activation='relu', kernel_regularizer=l2(0.001)))  # Increased units
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(num_classes, activation='softmax'))
    
    return model

# %%
def main():
    # Configuration parameters
    dataset_path = 'RAVDESS_mel_spectrograms'  # Update with your dataset path
    img_size = (192, 192)  # Increased from 128x128 to 192x192
    test_size = 0.15
    val_size = 0.15
    batch_size = 16
    max_epochs = 500
    
    # Load and preprocess data with larger image size
    X, y, class_names = load_data(dataset_path, img_size)
    print(f"Original dataset: {X.shape[0]} samples")
    print(f"Image shape: {X[0].shape}")
    
    # Apply data augmentation
    X_aug, y_aug = augment_data(X, y)
    print(f"Augmented dataset: {X_aug.shape[0]} samples")
    
    # Encode labels
    y_onehot, le = preprocess_labels(y_aug)
    
    # Create train, validation, and test sets
    # First split off the test set
    X_temp, X_test, y_temp, y_test = train_test_split(
        X_aug, y_onehot, test_size=test_size, random_state=42, 
        stratify=np.argmax(y_onehot, axis=1)
    )
    
    # Then split the remaining data into train and validation
    val_ratio = val_size / (1 - test_size)
    X_train, X_val, y_train, y_val = train_test_split(
        X_temp, y_temp, test_size=val_ratio, random_state=42,
        stratify=np.argmax(y_temp, axis=1)
    )
    
    print(f"Train: {X_train.shape[0]}, Validation: {X_val.shape[0]}, Test: {X_test.shape[0]}")
    
    # Build and compile the model for 192x192 inputs
    input_shape = X_train.shape[1:]  # (192, 192)
    num_classes = y_onehot.shape[1]
    model = build_hybrid_model_192(input_shape, num_classes)
    
    # Memory usage estimate
    param_count = model.count_params()
    print(f"Model has {param_count:,} parameters")
    
    # Create optimizer with learning rate
    initial_lr = 0.001
    optimizer = tf.keras.optimizers.Adam(learning_rate=initial_lr)
    
    model.compile(
        optimizer=optimizer,
        loss='categorical_crossentropy',
        metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
    )
    
    # Print model summary
    model.summary()
    
    # Callbacks for training
    checkpoint = ModelCheckpoint(
        'best_emotion_model_192x192.h5',
        monitor='val_loss',
        save_best_only=True,
        mode='min',
        verbose=1
    )
    
    early_stop = EarlyStopping(
        monitor='val_loss',
        patience=20,
        restore_best_weights=True,
        verbose=1
    )
    
    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=10,
        min_lr=1e-6,
        verbose=1
    )
    
    # Train the model
    history = model.fit(
        X_train, y_train,
        epochs=max_epochs,
        batch_size=batch_size,
        validation_data=(X_val, y_val),
        callbacks=[early_stop, checkpoint, reduce_lr],
        verbose=1
    )
    
    # Evaluate on the test set
    test_loss, test_acc, test_precision, test_recall = model.evaluate(X_test, y_test)
    print(f"Test Loss: {test_loss:.4f}")
    print(f"Test Accuracy: {test_acc:.4f}")
    print(f"Test Precision: {test_precision:.4f}")
    print(f"Test Recall: {test_recall:.4f}")
    
    # Generate predictions and evaluate in detail
    y_pred = model.predict(X_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true_classes = np.argmax(y_test, axis=1)
    
    # Print classification report
    print("\nClassification Report:")
    print(classification_report(
        y_true_classes, 
        y_pred_classes, 
        target_names=[le.inverse_transform([i])[0] for i in range(num_classes)]
    ))
    
    # Plot training history
    plt.figure(figsize=(12, 4))
    
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'], loc='lower right')
    
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(['Train', 'Validation'], loc='upper right')
    
    plt.tight_layout()
    plt.savefig('training_history_192x192.png')
    plt.show()

# %%
if __name__ == '__main__':
    main()
# Out:
# Found 192 images for class 'angry'.
# Found 192 images for class 'calm'.
# Found 192 images for class 'disgust'.
# Found 192 images for class 'fearful'.
# Found 192 images for class 'happy'.
# Found 96 images for class 'neutral'.
# Found 192 images for class 'sad'.
# Found 192 images for class 'surprised'.
# Original dataset: 1440 samples
# Image shape: (192, 192)
# Augmented dataset: 2319 samples
# Train: 1623, Validation: 348, Test: 348
# Model has 3,772,200 parameters
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_2 (Reshape)         (None, 192, 192, 1)       0
#
#  conv2d_5 (Conv2D)           (None, 192, 192, 32)      320
#
#  batch_normalization_7 (Batc  (None, 192, 192, 32)     128
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, 192, 192, 32)      9248
#
#  batch_normalization_8 (Batc  (None, 192, 192, 32)     128
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 96, 96, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 96, 96, 64)        18496
#
#  batch_normalization_9 (Batc  (None, 96, 96, 64)       256
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 96, 96, 64)        36928
#
#  batch_normalization_10 (Bat  (None, 96, 96, 64)       256
#  chNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 48, 48, 64)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 48, 48, 128)       73856
#
#  batch_normalization_11 (Bat  (None, 48, 48, 128)      512
#  chNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 24, 24, 128)      0
#  2D)
#
#  reshape_3 (Reshape)         (None, 24, 3072)          0
#
#  rnn_2 (RNN)                 (None, 24, 256)           3408896
#
#  dropout_4 (Dropout)         (None, 24, 256)           0
#
#  rnn_3 (RNN)                 (None, 128)               197120
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 128)               16512
#
#  batch_normalization_12 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  batch_normalization_13 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 8)                 520
#
# =================================================================
# Total params: 3,772,200
# Trainable params: 3,771,176
# Non-trainable params: 1,024
# _________________________________________________________________
# Epoch 1/500
# 102/102 [==============================] - ETA: 0s - loss: 3.1479 - accuracy: 0.1633 - precision_1: 0.1897 - recall_1: 0.0659
# Epoch 1: val_loss improved from inf to 2.52381, saving model to best_emotion_model_192x192.h5
# 102/102 [==============================] - 10s 84ms/step - loss: 3.1479 - accuracy: 0.1633 - precision_1: 0.1897 - recall_1: 0.0659 - val_loss: 2.5238 - val_accuracy: 0.1379 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 0.0010
# Epoch 2/500
# 102/102 [==============================] - ETA: 0s - loss: 2.9647 - accuracy: 0.1306 - precision_1: 0.1541 - recall_1: 0.0351
# Epoch 2: val_loss did not improve from 2.52381
# 102/102 [==============================] - 8s 80ms/step - loss: 2.9647 - accuracy: 0.1306 - precision_1: 0.1541 - recall_1: 0.0351 - val_loss: 2.7559 - val_accuracy: 0.1379 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 0.0010
# Epoch 3/500
# 102/102 [==============================] - ETA: 0s - loss: 2.7306 - accuracy: 0.1787 - precision_1: 0.2128 - recall_1: 0.0370
# Epoch 3: val_loss did not improve from 2.52381
# 102/102 [==============================] - 8s 79ms/step - loss: 2.7306 - accuracy: 0.1787 - precision_1: 0.2128 - recall_1: 0.0370 - val_loss: 2.6524 - val_accuracy: 0.1236 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 0.0010
# Epoch 4/500
# 102/102 [==============================] - ETA: 0s - loss: 2.6989 - accuracy: 0.1688 - precision_1: 0.1944 - recall_1: 0.0302
# Epoch 4: val_loss improved from 2.52381 to 2.43737, saving model to best_emotion_model_192x192.h5
# 102/102 [==============================] - 8s 80ms/step - loss: 2.6989 - accuracy: 0.1688 - precision_1: 0.1944 - recall_1: 0.0302 - val_loss: 2.4374 - val_accuracy: 0.1897 - val_precision_1: 1.0000 - val_recall_1: 0.0029 - lr: 0.0010
# Epoch 5/500
# 102/102 [==============================] - ETA: 0s - loss: 2.5463 - accuracy: 0.2169 - precision_1: 0.2615 - recall_1: 0.0351
# Epoch 5: val_loss improved from 2.43737 to 2.38757, saving model to best_emotion_model_192x192.h5
# 102/102 [==============================] - 8s 81ms/step - loss: 2.5463 - accuracy: 0.2169 - precision_1: 0.2615 - recall_1: 0.0351 - val_loss: 2.3876 - val_accuracy: 0.1466 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - lr: 0.0010
# Epoch 6/500
# 102/102 [==============================] - ETA: 0s - loss: 2.4970 - accuracy: 0.2058 - precision_1: 0.2928 - recall_1: 0.0327
# Epoch 6: val_loss did not improve from 2.38757
# 102/102 [==============================] - 8s 80ms/step - loss: 2.4970 - accuracy: 0.2058 - precision_1: 0.2928 - recall_1: 0.0327 - val_loss: 2.4925 - val_accuracy: 0.1839 - val_precision_1: 0.3077 - val_recall_1: 0.0575 - lr: 0.0010
# Epoch 7/500
# 102/102 [==============================] - ETA: 0s - loss: 2.3927 - accuracy: 0.2341 - precision_1: 0.3029 - recall_1: 0.0327
# Epoch 7: val_loss did not improve from 2.38757
# 102/102 [==============================] - 8s 78ms/step - loss: 2.3927 - accuracy: 0.2341 - precision_1: 0.3029 - recall_1: 0.0327 - val_loss: 2.4142 - val_accuracy: 0.2529 - val_precision_1: 0.3846 - val_recall_1: 0.0575 - lr: 0.0010
# Epoch 8/500
# 102/102 [==============================] - ETA: 0s - loss: 2.2915 - accuracy: 0.2612 - precision_1: 0.4115 - recall_1: 0.0530
# Epoch 8: val_loss did not improve from 2.38757
# 102/102 [==============================] - 8s 81ms/step - loss: 2.2915 - accuracy: 0.2612 - precision_1: 0.4115 - recall_1: 0.0530 - val_loss: 2.6053 - val_accuracy: 0.1753 - val_precision_1: 0.4074 - val_recall_1: 0.0316 - lr: 0.0010
# Epoch 9/500
# 102/102 [==============================] - ETA: 0s - loss: 2.3066 - accuracy: 0.2575 - precision_1: 0.4064 - recall_1: 0.0468
# Epoch 9: val_loss improved from 2.38757 to 2.34792, saving model to best_emotion_model_192x192.h5
# 102/102 [==============================] - 8s 82ms/step - loss: 2.3066 - accuracy: 0.2575 - precision_1: 0.4064 - recall_1: 0.0468 - val_loss: 2.3479 - val_accuracy: 0.2471 - val_precision_1: 0.5789 - val_recall_1: 0.0316 - lr: 0.0010
# Epoch 10/500
# 102/102 [==============================] - ETA: 0s - loss: 2.2113 - accuracy: 0.2816 - precision_1: 0.4649 - recall_1: 0.0530
# Epoch 10: val_loss improved from 2.34792 to 1.99307, saving model to best_emotion_model_192x192.h5
# 102/102 [==============================] - 8s 81ms/step - loss: 2.2113 - accuracy: 0.2816 - precision_1: 0.4649 - recall_1: 0.0530 - val_loss: 1.9931 - val_accuracy: 0.3851 - val_precision_1: 0.8696 - val_recall_1: 0.0575 - lr: 0.0010
# Epoch 11/500
# 102/102 [==============================] - ETA: 0s - loss: 2.1628 - accuracy: 0.2976 - precision_1: 0.4633 - recall_1: 0.0622
# Epoch 11: val_loss did not improve from 1.99307
# 102/102 [==============================] - 8s 80ms/step - loss: 2.1628 - accuracy: 0.2976 - precision_1: 0.4633 - recall_1: 0.0622 - val_loss: 2.4869 - val_accuracy: 0.2213 - val_precision_1: 0.4471 - val_recall_1: 0.1092 - lr: 0.0010
# Epoch 12/500
# 102/102 [==============================] - ETA: 0s - loss: 2.1192 - accuracy: 0.3235 - precision_1: 0.4747 - recall_1: 0.0752
# Epoch 12: val_loss did not improve from 1.99307
# 102/102 [==============================] - 8s 80ms/step - loss: 2.1192 - accuracy: 0.3235 - precision_1: 0.4747 - recall_1: 0.0752 - val_loss: 3.2014 - val_accuracy: 0.1810 - val_precision_1: 0.1646 - val_recall_1: 0.0374 - lr: 0.0010
# Epoch 13/500
# 102/102 [==============================] - ETA: 0s - loss: 2.0817 - accuracy: 0.3229 - precision_1: 0.5471 - recall_1: 0.0930
# Epoch 13: val_loss improved from 1.99307 to 1.95959, saving model to best_emotion_model_192x192.h5
# 102/102 [==============================] - 8s 80ms/step - loss: 2.0817 - accuracy: 0.3229 - precision_1: 0.5471 - recall_1: 0.0930 - val_loss: 1.9596 - val_accuracy: 0.3764 - val_precision_1: 0.5972 - val_recall_1: 0.2471 - lr: 0.0010
# Epoch 14/500
# 102/102 [==============================] - ETA: 0s - loss: 1.9955 - accuracy: 0.3592 - precision_1: 0.5473 - recall_1: 0.1177
# Epoch 14: val_loss improved from 1.95959 to 1.82375, saving model to best_emotion_model_192x192.h5
# 102/102 [==============================] - 8s 83ms/step - loss: 1.9955 - accuracy: 0.3592 - precision_1: 0.5473 - recall_1: 0.1177 - val_loss: 1.8238 - val_accuracy: 0.4598 - val_precision_1: 0.8219 - val_recall_1: 0.1724 - lr: 0.0010
# Epoch 15/500
# 102/102 [==============================] - ETA: 0s - loss: 1.9389 - accuracy: 0.3974 - precision_1: 0.5928 - recall_1: 0.1319
# Epoch 15: val_loss did not improve from 1.82375
# 102/102 [==============================] - 8s 81ms/step - loss: 1.9389 - accuracy: 0.3974 - precision_1: 0.5928 - recall_1: 0.1319 - val_loss: 1.8796 - val_accuracy: 0.4195 - val_precision_1: 0.5983 - val_recall_1: 0.2011 - lr: 0.0010
# Epoch 16/500
# 102/102 [==============================] - ETA: 0s - loss: 1.8855 - accuracy: 0.4085 - precision_1: 0.6229 - recall_1: 0.1608
# Epoch 16: val_loss did not improve from 1.82375
# 102/102 [==============================] - 8s 81ms/step - loss: 1.8855 - accuracy: 0.4085 - precision_1: 0.6229 - recall_1: 0.1608 - val_loss: 1.9230 - val_accuracy: 0.3994 - val_precision_1: 0.6531 - val_recall_1: 0.2759 - lr: 0.0010
# Epoch 17/500
# 102/102 [==============================] - ETA: 0s - loss: 1.8446 - accuracy: 0.4405 - precision_1: 0.6056 - recall_1: 0.1996
# Epoch 17: val_loss improved from 1.82375 to 1.73034, saving model to best_emotion_model_192x192.h5
# 102/102 [==============================] - 8s 83ms/step - loss: 1.8446 - accuracy: 0.4405 - precision_1: 0.6056 - recall_1: 0.1996 - val_loss: 1.7303 - val_accuracy: 0.4655 - val_precision_1: 0.7766 - val_recall_1: 0.2098 - lr: 0.0010
# Epoch 18/500
# 102/102 [==============================] - ETA: 0s - loss: 1.7587 - accuracy: 0.4640 - precision_1: 0.6718 - recall_1: 0.2157
# Epoch 18: val_loss did not improve from 1.73034
# 102/102 [==============================] - 8s 82ms/step - loss: 1.7587 - accuracy: 0.4640 - precision_1: 0.6718 - recall_1: 0.2157 - val_loss: 1.8566 - val_accuracy: 0.4253 - val_precision_1: 0.6077 - val_recall_1: 0.2270 - lr: 0.0010
# Epoch 19/500
# 102/102 [==============================] - ETA: 0s - loss: 1.7351 - accuracy: 0.4713 - precision_1: 0.6418 - recall_1: 0.2384
# Epoch 19: val_loss did not improve from 1.73034
# 102/102 [==============================] - 8s 83ms/step - loss: 1.7351 - accuracy: 0.4713 - precision_1: 0.6418 - recall_1: 0.2384 - val_loss: 3.0467 - val_accuracy: 0.1667 - val_precision_1: 0.2308 - val_recall_1: 0.1207 - lr: 0.0010
# Epoch 20/500
# 102/102 [==============================] - ETA: 0s - loss: 1.6989 - accuracy: 0.4744 - precision_1: 0.6733 - recall_1: 0.2514
# Epoch 20: val_loss did not improve from 1.73034
# 102/102 [==============================] - 8s 81ms/step - loss: 1.6989 - accuracy: 0.4744 - precision_1: 0.6733 - recall_1: 0.2514 - val_loss: 1.7804 - val_accuracy: 0.4368 - val_precision_1: 0.5824 - val_recall_1: 0.3046 - lr: 0.0010
# Epoch 21/500
# 102/102 [==============================] - ETA: 0s - loss: 1.6006 - accuracy: 0.5114 - precision_1: 0.7204 - recall_1: 0.3001
# Epoch 21: val_loss did not improve from 1.73034
# 102/102 [==============================] - 8s 81ms/step - loss: 1.6006 - accuracy: 0.5114 - precision_1: 0.7204 - recall_1: 0.3001 - val_loss: 2.0182 - val_accuracy: 0.3822 - val_precision_1: 0.4819 - val_recall_1: 0.2299 - lr: 0.0010
# Epoch 22/500
# 102/102 [==============================] - ETA: 0s - loss: 1.5984 - accuracy: 0.5071 - precision_1: 0.6762 - recall_1: 0.3062
# Epoch 22: val_loss did not improve from 1.73034
# 102/102 [==============================] - 8s 79ms/step - loss: 1.5984 - accuracy: 0.5071 - precision_1: 0.6762 - recall_1: 0.3062 - val_loss: 1.9149 - val_accuracy: 0.4655 - val_precision_1: 0.6085 - val_recall_1: 0.3305 - lr: 0.0010
# Epoch 23/500
# 102/102 [==============================] - ETA: 0s - loss: 1.5163 - accuracy: 0.5354 - precision_1: 0.7039 - recall_1: 0.3266
# Epoch 23: val_loss did not improve from 1.73034
# 102/102 [==============================] - 8s 80ms/step - loss: 1.5163 - accuracy: 0.5354 - precision_1: 0.7039 - recall_1: 0.3266 - val_loss: 1.8079 - val_accuracy: 0.4310 - val_precision_1: 0.5868 - val_recall_1: 0.2816 - lr: 0.0010
# Epoch 24/500
# 102/102 [==============================] - ETA: 0s - loss: 1.5075 - accuracy: 0.5416 - precision_1: 0.7141 - recall_1: 0.3555
# Epoch 24: val_loss improved from 1.73034 to 1.39419, saving model to best_emotion_model_192x192.h5
# 102/102 [==============================] - 8s 82ms/step - loss: 1.5075 - accuracy: 0.5416 - precision_1: 0.7141 - recall_1: 0.3555 - val_loss: 1.3942 - val_accuracy: 0.6149 - val_precision_1: 0.8023 - val_recall_1: 0.3966 - lr: 0.0010
# Epoch 25/500
# 102/102 [==============================] - ETA: 0s - loss: 1.4423 - accuracy: 0.5607 - precision_1: 0.7357 - recall_1: 0.3722
# Epoch 25: val_loss did not improve from 1.39419
# 102/102 [==============================] - 8s 79ms/step - loss: 1.4423 - accuracy: 0.5607 - precision_1: 0.7357 - recall_1: 0.3722 - val_loss: 1.8082 - val_accuracy: 0.4454 - val_precision_1: 0.5966 - val_recall_1: 0.3017 - lr: 0.0010
# Epoch 26/500
# 102/102 [==============================] - ETA: 0s - loss: 1.3536 - accuracy: 0.6124 - precision_1: 0.7581 - recall_1: 0.4190
# Epoch 26: val_loss improved from 1.39419 to 1.30269, saving model to best_emotion_model_192x192.h5
# 102/102 [==============================] - 8s 80ms/step - loss: 1.3536 - accuracy: 0.6124 - precision_1: 0.7581 - recall_1: 0.4190 - val_loss: 1.3027 - val_accuracy: 0.6379 - val_precision_1: 0.7568 - val_recall_1: 0.4828 - lr: 0.0010
# Epoch 27/500
# 102/102 [==============================] - ETA: 0s - loss: 1.3412 - accuracy: 0.6143 - precision_1: 0.7438 - recall_1: 0.4436
# Epoch 27: val_loss did not improve from 1.30269
# 102/102 [==============================] - 8s 80ms/step - loss: 1.3412 - accuracy: 0.6143 - precision_1: 0.7438 - recall_1: 0.4436 - val_loss: 2.5429 - val_accuracy: 0.4080 - val_precision_1: 0.4342 - val_recall_1: 0.3506 - lr: 0.0010
# Epoch 28/500
# 102/102 [==============================] - ETA: 0s - loss: 1.3462 - accuracy: 0.6094 - precision_1: 0.7282 - recall_1: 0.4424
# Epoch 28: val_loss did not improve from 1.30269
# 102/102 [==============================] - 8s 80ms/step - loss: 1.3462 - accuracy: 0.6094 - precision_1: 0.7282 - recall_1: 0.4424 - val_loss: 1.6608 - val_accuracy: 0.5115 - val_precision_1: 0.6389 - val_recall_1: 0.3966 - lr: 0.0010
# Epoch 29/500
# 102/102 [==============================] - ETA: 0s - loss: 1.2762 - accuracy: 0.6389 - precision_1: 0.7693 - recall_1: 0.4849
# Epoch 29: val_loss did not improve from 1.30269
# 102/102 [==============================] - 8s 81ms/step - loss: 1.2762 - accuracy: 0.6389 - precision_1: 0.7693 - recall_1: 0.4849 - val_loss: 1.5737 - val_accuracy: 0.4828 - val_precision_1: 0.6043 - val_recall_1: 0.4080 - lr: 0.0010
# Epoch 30/500
# 102/102 [==============================] - ETA: 0s - loss: 1.2129 - accuracy: 0.6667 - precision_1: 0.7669 - recall_1: 0.5231
# Epoch 30: val_loss improved from 1.30269 to 1.27070, saving model to best_emotion_model_192x192.h5
# 102/102 [==============================] - 8s 82ms/step - loss: 1.2129 - accuracy: 0.6667 - precision_1: 0.7669 - recall_1: 0.5231 - val_loss: 1.2707 - val_accuracy: 0.6695 - val_precision_1: 0.7554 - val_recall_1: 0.5057 - lr: 0.0010
# Epoch 31/500
# 102/102 [==============================] - ETA: 0s - loss: 1.1366 - accuracy: 0.6987 - precision_1: 0.7925 - recall_1: 0.5767
# Epoch 31: val_loss did not improve from 1.27070
# 102/102 [==============================] - 8s 82ms/step - loss: 1.1366 - accuracy: 0.6987 - precision_1: 0.7925 - recall_1: 0.5767 - val_loss: 1.9038 - val_accuracy: 0.4885 - val_precision_1: 0.5530 - val_recall_1: 0.4195 - lr: 0.0010
# Epoch 32/500
# 102/102 [==============================] - ETA: 0s - loss: 1.0893 - accuracy: 0.7246 - precision_1: 0.8016 - recall_1: 0.6124
# Epoch 32: val_loss did not improve from 1.27070
# 102/102 [==============================] - 8s 80ms/step - loss: 1.0893 - accuracy: 0.7246 - precision_1: 0.8016 - recall_1: 0.6124 - val_loss: 1.6351 - val_accuracy: 0.5259 - val_precision_1: 0.6047 - val_recall_1: 0.4397 - lr: 0.0010
# Epoch 33/500
# 102/102 [==============================] - ETA: 0s - loss: 1.0679 - accuracy: 0.7203 - precision_1: 0.7937 - recall_1: 0.6377
# Epoch 33: val_loss improved from 1.27070 to 1.21621, saving model to best_emotion_model_192x192.h5
# 102/102 [==============================] - 8s 82ms/step - loss: 1.0679 - accuracy: 0.7203 - precision_1: 0.7937 - recall_1: 0.6377 - val_loss: 1.2162 - val_accuracy: 0.6466 - val_precision_1: 0.6997 - val_recall_1: 0.5891 - lr: 0.0010
# Epoch 34/500
# 102/102 [==============================] - ETA: 0s - loss: 1.0481 - accuracy: 0.7234 - precision_1: 0.8018 - recall_1: 0.6506
# Epoch 34: val_loss did not improve from 1.21621
# 102/102 [==============================] - 8s 80ms/step - loss: 1.0481 - accuracy: 0.7234 - precision_1: 0.8018 - recall_1: 0.6506 - val_loss: 1.4821 - val_accuracy: 0.5517 - val_precision_1: 0.6194 - val_recall_1: 0.5144 - lr: 0.0010
# Epoch 35/500
# 102/102 [==============================] - ETA: 0s - loss: 0.9711 - accuracy: 0.7511 - precision_1: 0.8233 - recall_1: 0.6802
# Epoch 35: val_loss did not improve from 1.21621
# 102/102 [==============================] - 8s 81ms/step - loss: 0.9711 - accuracy: 0.7511 - precision_1: 0.8233 - recall_1: 0.6802 - val_loss: 1.2509 - val_accuracy: 0.6609 - val_precision_1: 0.7000 - val_recall_1: 0.6034 - lr: 0.0010
# Epoch 36/500
# 102/102 [==============================] - ETA: 0s - loss: 0.9471 - accuracy: 0.7659 - precision_1: 0.8137 - recall_1: 0.6969
# Epoch 36: val_loss did not improve from 1.21621
# 102/102 [==============================] - 8s 80ms/step - loss: 0.9471 - accuracy: 0.7659 - precision_1: 0.8137 - recall_1: 0.6969 - val_loss: 1.6047 - val_accuracy: 0.5747 - val_precision_1: 0.6081 - val_recall_1: 0.5172 - lr: 0.0010
# Epoch 37/500
# 102/102 [==============================] - ETA: 0s - loss: 0.8795 - accuracy: 0.7979 - precision_1: 0.8405 - recall_1: 0.7437
# Epoch 37: val_loss did not improve from 1.21621
# 102/102 [==============================] - 8s 80ms/step - loss: 0.8795 - accuracy: 0.7979 - precision_1: 0.8405 - recall_1: 0.7437 - val_loss: 1.5581 - val_accuracy: 0.5977 - val_precision_1: 0.6318 - val_recall_1: 0.5374 - lr: 0.0010
# Epoch 38/500
# 102/102 [==============================] - ETA: 0s - loss: 0.8756 - accuracy: 0.7973 - precision_1: 0.8398 - recall_1: 0.7492
# Epoch 38: val_loss did not improve from 1.21621
# 102/102 [==============================] - 8s 81ms/step - loss: 0.8756 - accuracy: 0.7973 - precision_1: 0.8398 - recall_1: 0.7492 - val_loss: 1.4727 - val_accuracy: 0.6178 - val_precision_1: 0.6458 - val_recall_1: 0.5920 - lr: 0.0010
# Epoch 39/500
# 102/102 [==============================] - ETA: 0s - loss: 0.7542 - accuracy: 0.8349 - precision_1: 0.8693 - recall_1: 0.7948
# Epoch 39: val_loss did not improve from 1.21621
# 102/102 [==============================] - 8s 80ms/step - loss: 0.7542 - accuracy: 0.8349 - precision_1: 0.8693 - recall_1: 0.7948 - val_loss: 1.3714 - val_accuracy: 0.6437 - val_precision_1: 0.6770 - val_recall_1: 0.6264 - lr: 0.0010
# Epoch 40/500
# 102/102 [==============================] - ETA: 0s - loss: 0.7654 - accuracy: 0.8293 - precision_1: 0.8571 - recall_1: 0.7911
# Epoch 40: val_loss improved from 1.21621 to 1.15931, saving model to best_emotion_model_192x192.h5
# 102/102 [==============================] - 8s 82ms/step - loss: 0.7654 - accuracy: 0.8293 - precision_1: 0.8571 - recall_1: 0.7911 - val_loss: 1.1593 - val_accuracy: 0.7414 - val_precision_1: 0.7590 - val_recall_1: 0.7241 - lr: 0.0010
# Epoch 41/500
# 102/102 [==============================] - ETA: 0s - loss: 0.7330 - accuracy: 0.8441 - precision_1: 0.8735 - recall_1: 0.8170
# Epoch 41: val_loss did not improve from 1.15931
# 102/102 [==============================] - 8s 83ms/step - loss: 0.7330 - accuracy: 0.8441 - precision_1: 0.8735 - recall_1: 0.8170 - val_loss: 2.0891 - val_accuracy: 0.4914 - val_precision_1: 0.5091 - val_recall_1: 0.4799 - lr: 0.0010
# Epoch 42/500
# 102/102 [==============================] - ETA: 0s - loss: 0.7156 - accuracy: 0.8503 - precision_1: 0.8761 - recall_1: 0.8232
# Epoch 42: val_loss did not improve from 1.15931
# 102/102 [==============================] - 8s 81ms/step - loss: 0.7156 - accuracy: 0.8503 - precision_1: 0.8761 - recall_1: 0.8232 - val_loss: 1.3081 - val_accuracy: 0.6580 - val_precision_1: 0.6991 - val_recall_1: 0.6408 - lr: 0.0010
# Epoch 43/500
# 102/102 [==============================] - ETA: 0s - loss: 0.6485 - accuracy: 0.8737 - precision_1: 0.8975 - recall_1: 0.8521
# Epoch 43: val_loss did not improve from 1.15931
# 102/102 [==============================] - 8s 80ms/step - loss: 0.6485 - accuracy: 0.8737 - precision_1: 0.8975 - recall_1: 0.8521 - val_loss: 1.3379 - val_accuracy: 0.7040 - val_precision_1: 0.7323 - val_recall_1: 0.6839 - lr: 0.0010
# Epoch 44/500
# 102/102 [==============================] - ETA: 0s - loss: 0.6835 - accuracy: 0.8651 - precision_1: 0.8941 - recall_1: 0.8373
# Epoch 44: val_loss improved from 1.15931 to 1.07553, saving model to best_emotion_model_192x192.h5
# 102/102 [==============================] - 8s 83ms/step - loss: 0.6835 - accuracy: 0.8651 - precision_1: 0.8941 - recall_1: 0.8373 - val_loss: 1.0755 - val_accuracy: 0.7557 - val_precision_1: 0.7754 - val_recall_1: 0.7443 - lr: 0.0010
# Epoch 45/500
# 102/102 [==============================] - ETA: 0s - loss: 0.6465 - accuracy: 0.8737 - precision_1: 0.8939 - recall_1: 0.8564
# Epoch 45: val_loss did not improve from 1.07553
# 102/102 [==============================] - 8s 81ms/step - loss: 0.6465 - accuracy: 0.8737 - precision_1: 0.8939 - recall_1: 0.8564 - val_loss: 1.9887 - val_accuracy: 0.5690 - val_precision_1: 0.5714 - val_recall_1: 0.5402 - lr: 0.0010
# Epoch 46/500
# 102/102 [==============================] - ETA: 0s - loss: 0.5322 - accuracy: 0.9131 - precision_1: 0.9302 - recall_1: 0.8946
# Epoch 46: val_loss did not improve from 1.07553
# 102/102 [==============================] - 8s 80ms/step - loss: 0.5322 - accuracy: 0.9131 - precision_1: 0.9302 - recall_1: 0.8946 - val_loss: 1.2775 - val_accuracy: 0.7471 - val_precision_1: 0.7544 - val_recall_1: 0.7414 - lr: 0.0010
# Epoch 47/500
# 102/102 [==============================] - ETA: 0s - loss: 0.6530 - accuracy: 0.8774 - precision_1: 0.8912 - recall_1: 0.8632
# Epoch 47: val_loss did not improve from 1.07553
# 102/102 [==============================] - 8s 81ms/step - loss: 0.6530 - accuracy: 0.8774 - precision_1: 0.8912 - recall_1: 0.8632 - val_loss: 1.1291 - val_accuracy: 0.7787 - val_precision_1: 0.8000 - val_recall_1: 0.7586 - lr: 0.0010
# Epoch 48/500
# 102/102 [==============================] - ETA: 0s - loss: 0.6556 - accuracy: 0.8891 - precision_1: 0.9008 - recall_1: 0.8731
# Epoch 48: val_loss did not improve from 1.07553
# 102/102 [==============================] - 8s 81ms/step - loss: 0.6556 - accuracy: 0.8891 - precision_1: 0.9008 - recall_1: 0.8731 - val_loss: 1.2700 - val_accuracy: 0.6983 - val_precision_1: 0.7210 - val_recall_1: 0.6609 - lr: 0.0010
# Epoch 49/500
# 102/102 [==============================] - ETA: 0s - loss: 0.5618 - accuracy: 0.9094 - precision_1: 0.9197 - recall_1: 0.8959
# Epoch 49: val_loss did not improve from 1.07553
# 102/102 [==============================] - 8s 80ms/step - loss: 0.5618 - accuracy: 0.9094 - precision_1: 0.9197 - recall_1: 0.8959 - val_loss: 1.7657 - val_accuracy: 0.6121 - val_precision_1: 0.6355 - val_recall_1: 0.6063 - lr: 0.0010
# Epoch 50/500
# 102/102 [==============================] - ETA: 0s - loss: 0.5551 - accuracy: 0.9070 - precision_1: 0.9244 - recall_1: 0.8971
# Epoch 50: val_loss did not improve from 1.07553
# 102/102 [==============================] - 8s 81ms/step - loss: 0.5551 - accuracy: 0.9070 - precision_1: 0.9244 - recall_1: 0.8971 - val_loss: 1.3934 - val_accuracy: 0.7126 - val_precision_1: 0.7319 - val_recall_1: 0.6983 - lr: 0.0010
# Epoch 51/500
# 102/102 [==============================] - ETA: 0s - loss: 0.5829 - accuracy: 0.8965 - precision_1: 0.9102 - recall_1: 0.8866
# Epoch 51: val_loss did not improve from 1.07553
# 102/102 [==============================] - 8s 81ms/step - loss: 0.5829 - accuracy: 0.8965 - precision_1: 0.9102 - recall_1: 0.8866 - val_loss: 1.2435 - val_accuracy: 0.7385 - val_precision_1: 0.7751 - val_recall_1: 0.7328 - lr: 0.0010
# Epoch 52/500
# 102/102 [==============================] - ETA: 0s - loss: 0.5890 - accuracy: 0.9057 - precision_1: 0.9190 - recall_1: 0.8953
# Epoch 52: val_loss did not improve from 1.07553
# 102/102 [==============================] - 8s 81ms/step - loss: 0.5890 - accuracy: 0.9057 - precision_1: 0.9190 - recall_1: 0.8953 - val_loss: 1.3555 - val_accuracy: 0.7011 - val_precision_1: 0.7331 - val_recall_1: 0.6868 - lr: 0.0010
# Epoch 53/500
# 102/102 [==============================] - ETA: 0s - loss: 0.5505 - accuracy: 0.9063 - precision_1: 0.9246 - recall_1: 0.8922
# Epoch 53: val_loss did not improve from 1.07553
# 102/102 [==============================] - 8s 81ms/step - loss: 0.5505 - accuracy: 0.9063 - precision_1: 0.9246 - recall_1: 0.8922 - val_loss: 1.3952 - val_accuracy: 0.6839 - val_precision_1: 0.6960 - val_recall_1: 0.6580 - lr: 0.0010
# Epoch 54/500
# 102/102 [==============================] - ETA: 0s - loss: 0.5533 - accuracy: 0.9082 - precision_1: 0.9236 - recall_1: 0.8934
# Epoch 54: val_loss did not improve from 1.07553
# 102/102 [==============================] - 8s 81ms/step - loss: 0.5533 - accuracy: 0.9082 - precision_1: 0.9236 - recall_1: 0.8934 - val_loss: 1.5317 - val_accuracy: 0.6638 - val_precision_1: 0.6696 - val_recall_1: 0.6523 - lr: 0.0010
# Epoch 55/500
# 102/102 [==============================] - ETA: 0s - loss: 0.5888 - accuracy: 0.8990 - precision_1: 0.9169 - recall_1: 0.8842
# Epoch 55: val_loss did not improve from 1.07553
# 102/102 [==============================] - 8s 83ms/step - loss: 0.5888 - accuracy: 0.8990 - precision_1: 0.9169 - recall_1: 0.8842 - val_loss: 1.2612 - val_accuracy: 0.7299 - val_precision_1: 0.7530 - val_recall_1: 0.7184 - lr: 0.0010
# Epoch 56/500
# 102/102 [==============================] - ETA: 0s - loss: 0.5401 - accuracy: 0.9174 - precision_1: 0.9313 - recall_1: 0.9026
# Epoch 56: val_loss did not improve from 1.07553
# 102/102 [==============================] - 8s 80ms/step - loss: 0.5401 - accuracy: 0.9174 - precision_1: 0.9313 - recall_1: 0.9026 - val_loss: 1.3986 - val_accuracy: 0.7328 - val_precision_1: 0.7455 - val_recall_1: 0.7155 - lr: 0.0010
# Epoch 57/500
# 102/102 [==============================] - ETA: 0s - loss: 0.4744 - accuracy: 0.9384 - precision_1: 0.9452 - recall_1: 0.9254
# Epoch 57: val_loss did not improve from 1.07553
# 102/102 [==============================] - 8s 81ms/step - loss: 0.4744 - accuracy: 0.9384 - precision_1: 0.9452 - recall_1: 0.9254 - val_loss: 1.2246 - val_accuracy: 0.7557 - val_precision_1: 0.7731 - val_recall_1: 0.7443 - lr: 0.0010
# Epoch 58/500
# 102/102 [==============================] - ETA: 0s - loss: 0.4926 - accuracy: 0.9261 - precision_1: 0.9413 - recall_1: 0.9187
# Epoch 58: val_loss did not improve from 1.07553
# 102/102 [==============================] - 8s 80ms/step - loss: 0.4926 - accuracy: 0.9261 - precision_1: 0.9413 - recall_1: 0.9187 - val_loss: 1.6482 - val_accuracy: 0.6609 - val_precision_1: 0.6686 - val_recall_1: 0.6494 - lr: 0.0010
# Epoch 59/500
# 102/102 [==============================] - ETA: 0s - loss: 0.6596 - accuracy: 0.8811 - precision_1: 0.8964 - recall_1: 0.8632
# Epoch 59: val_loss did not improve from 1.07553
# 102/102 [==============================] - 8s 80ms/step - loss: 0.6596 - accuracy: 0.8811 - precision_1: 0.8964 - recall_1: 0.8632 - val_loss: 1.9494 - val_accuracy: 0.5920 - val_precision_1: 0.6012 - val_recall_1: 0.5718 - lr: 0.0010
# Epoch 60/500
# 102/102 [==============================] - ETA: 0s - loss: 0.4603 - accuracy: 0.9433 - precision_1: 0.9499 - recall_1: 0.9341
# Epoch 60: val_loss did not improve from 1.07553
# 102/102 [==============================] - 8s 83ms/step - loss: 0.4603 - accuracy: 0.9433 - precision_1: 0.9499 - recall_1: 0.9341 - val_loss: 1.2428 - val_accuracy: 0.7529 - val_precision_1: 0.7745 - val_recall_1: 0.7500 - lr: 0.0010
# Epoch 61/500
# 102/102 [==============================] - ETA: 0s - loss: 0.4639 - accuracy: 0.9316 - precision_1: 0.9420 - recall_1: 0.9205
# Epoch 61: val_loss did not improve from 1.07553
# 102/102 [==============================] - 8s 81ms/step - loss: 0.4639 - accuracy: 0.9316 - precision_1: 0.9420 - recall_1: 0.9205 - val_loss: 1.3802 - val_accuracy: 0.7126 - val_precision_1: 0.7351 - val_recall_1: 0.7098 - lr: 0.0010
# Epoch 62/500
# 102/102 [==============================] - ETA: 0s - loss: 0.4498 - accuracy: 0.9384 - precision_1: 0.9452 - recall_1: 0.9347
# Epoch 62: val_loss did not improve from 1.07553
# 102/102 [==============================] - 8s 83ms/step - loss: 0.4498 - accuracy: 0.9384 - precision_1: 0.9452 - recall_1: 0.9347 - val_loss: 1.0845 - val_accuracy: 0.7845 - val_precision_1: 0.8006 - val_recall_1: 0.7730 - lr: 0.0010
# Epoch 63/500
# 102/102 [==============================] - ETA: 0s - loss: 0.4333 - accuracy: 0.9452 - precision_1: 0.9538 - recall_1: 0.9415
# Epoch 63: val_loss did not improve from 1.07553
# 102/102 [==============================] - 8s 81ms/step - loss: 0.4333 - accuracy: 0.9452 - precision_1: 0.9538 - recall_1: 0.9415 - val_loss: 1.1859 - val_accuracy: 0.7845 - val_precision_1: 0.8018 - val_recall_1: 0.7787 - lr: 0.0010
# Epoch 64/500
# 102/102 [==============================] - ETA: 0s - loss: 0.4495 - accuracy: 0.9439 - precision_1: 0.9530 - recall_1: 0.9378
# Epoch 64: val_loss did not improve from 1.07553
#
# Epoch 64: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 102/102 [==============================] - 8s 81ms/step - loss: 0.4495 - accuracy: 0.9439 - precision_1: 0.9530 - recall_1: 0.9378 - val_loss: 1.3557 - val_accuracy: 0.7586 - val_precision_1: 0.7647 - val_recall_1: 0.7471 - lr: 0.0010
# Epoch 65/500
# 102/102 [==============================] - ETA: 0s - loss: 0.4065 - accuracy: 0.9544 - precision_1: 0.9607 - recall_1: 0.9495
# Epoch 65: val_loss improved from 1.07553 to 1.05946, saving model to best_emotion_model_192x192.h5
# 102/102 [==============================] - 8s 81ms/step - loss: 0.4065 - accuracy: 0.9544 - precision_1: 0.9607 - recall_1: 0.9495 - val_loss: 1.0595 - val_accuracy: 0.8046 - val_precision_1: 0.8069 - val_recall_1: 0.8046 - lr: 5.0000e-04
# Epoch 66/500
# 102/102 [==============================] - ETA: 0s - loss: 0.2865 - accuracy: 0.9883 - precision_1: 0.9889 - recall_1: 0.9858
# Epoch 66: val_loss improved from 1.05946 to 1.05027, saving model to best_emotion_model_192x192.h5
# 102/102 [==============================] - 8s 82ms/step - loss: 0.2865 - accuracy: 0.9883 - precision_1: 0.9889 - recall_1: 0.9858 - val_loss: 1.0503 - val_accuracy: 0.8333 - val_precision_1: 0.8363 - val_recall_1: 0.8218 - lr: 5.0000e-04
# Epoch 67/500
# 102/102 [==============================] - ETA: 0s - loss: 0.2656 - accuracy: 0.9901 - precision_1: 0.9938 - recall_1: 0.9877
# Epoch 67: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 81ms/step - loss: 0.2656 - accuracy: 0.9901 - precision_1: 0.9938 - recall_1: 0.9877 - val_loss: 1.1937 - val_accuracy: 0.7989 - val_precision_1: 0.8047 - val_recall_1: 0.7931 - lr: 5.0000e-04
# Epoch 68/500
# 102/102 [==============================] - ETA: 0s - loss: 0.2669 - accuracy: 0.9889 - precision_1: 0.9913 - recall_1: 0.9883
# Epoch 68: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 81ms/step - loss: 0.2669 - accuracy: 0.9889 - precision_1: 0.9913 - recall_1: 0.9883 - val_loss: 1.1393 - val_accuracy: 0.8103 - val_precision_1: 0.8150 - val_recall_1: 0.8103 - lr: 5.0000e-04
# Epoch 69/500
# 102/102 [==============================] - ETA: 0s - loss: 0.2493 - accuracy: 0.9901 - precision_1: 0.9907 - recall_1: 0.9895
# Epoch 69: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 82ms/step - loss: 0.2493 - accuracy: 0.9901 - precision_1: 0.9907 - recall_1: 0.9895 - val_loss: 1.2087 - val_accuracy: 0.8046 - val_precision_1: 0.8064 - val_recall_1: 0.8017 - lr: 5.0000e-04
# Epoch 70/500
# 102/102 [==============================] - ETA: 0s - loss: 0.2581 - accuracy: 0.9834 - precision_1: 0.9846 - recall_1: 0.9821
# Epoch 70: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 81ms/step - loss: 0.2581 - accuracy: 0.9834 - precision_1: 0.9846 - recall_1: 0.9821 - val_loss: 1.1519 - val_accuracy: 0.8190 - val_precision_1: 0.8237 - val_recall_1: 0.8190 - lr: 5.0000e-04
# Epoch 71/500
# 102/102 [==============================] - ETA: 0s - loss: 0.2543 - accuracy: 0.9864 - precision_1: 0.9882 - recall_1: 0.9846
# Epoch 71: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 82ms/step - loss: 0.2543 - accuracy: 0.9864 - precision_1: 0.9882 - recall_1: 0.9846 - val_loss: 1.2243 - val_accuracy: 0.8103 - val_precision_1: 0.8150 - val_recall_1: 0.8103 - lr: 5.0000e-04
# Epoch 72/500
# 102/102 [==============================] - ETA: 0s - loss: 0.2230 - accuracy: 0.9920 - precision_1: 0.9926 - recall_1: 0.9914
# Epoch 72: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 83ms/step - loss: 0.2230 - accuracy: 0.9920 - precision_1: 0.9926 - recall_1: 0.9914 - val_loss: 1.1772 - val_accuracy: 0.8132 - val_precision_1: 0.8150 - val_recall_1: 0.8103 - lr: 5.0000e-04
# Epoch 73/500
# 102/102 [==============================] - ETA: 0s - loss: 0.2160 - accuracy: 0.9938 - precision_1: 0.9951 - recall_1: 0.9920
# Epoch 73: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 79ms/step - loss: 0.2160 - accuracy: 0.9938 - precision_1: 0.9951 - recall_1: 0.9920 - val_loss: 1.2592 - val_accuracy: 0.8161 - val_precision_1: 0.8203 - val_recall_1: 0.8132 - lr: 5.0000e-04
# Epoch 74/500
# 102/102 [==============================] - ETA: 0s - loss: 0.2248 - accuracy: 0.9858 - precision_1: 0.9864 - recall_1: 0.9846
# Epoch 74: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 79ms/step - loss: 0.2248 - accuracy: 0.9858 - precision_1: 0.9864 - recall_1: 0.9846 - val_loss: 2.2041 - val_accuracy: 0.6552 - val_precision_1: 0.6628 - val_recall_1: 0.6552 - lr: 5.0000e-04
# Epoch 75/500
# 102/102 [==============================] - ETA: 0s - loss: 0.2547 - accuracy: 0.9784 - precision_1: 0.9814 - recall_1: 0.9766
# Epoch 75: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 80ms/step - loss: 0.2547 - accuracy: 0.9784 - precision_1: 0.9814 - recall_1: 0.9766 - val_loss: 2.0604 - val_accuracy: 0.6580 - val_precision_1: 0.6627 - val_recall_1: 0.6437 - lr: 5.0000e-04
# Epoch 76/500
# 102/102 [==============================] - ETA: 0s - loss: 0.2475 - accuracy: 0.9846 - precision_1: 0.9846 - recall_1: 0.9827
# Epoch 76: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 79ms/step - loss: 0.2475 - accuracy: 0.9846 - precision_1: 0.9846 - recall_1: 0.9827 - val_loss: 1.7914 - val_accuracy: 0.7213 - val_precision_1: 0.7310 - val_recall_1: 0.7184 - lr: 5.0000e-04
# Epoch 77/500
# 102/102 [==============================] - ETA: 0s - loss: 0.2833 - accuracy: 0.9723 - precision_1: 0.9770 - recall_1: 0.9704
# Epoch 77: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 79ms/step - loss: 0.2833 - accuracy: 0.9723 - precision_1: 0.9770 - recall_1: 0.9704 - val_loss: 1.3026 - val_accuracy: 0.7845 - val_precision_1: 0.7884 - val_recall_1: 0.7816 - lr: 5.0000e-04
# Epoch 78/500
# 102/102 [==============================] - ETA: 0s - loss: 0.3011 - accuracy: 0.9667 - precision_1: 0.9691 - recall_1: 0.9649
# Epoch 78: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 81ms/step - loss: 0.3011 - accuracy: 0.9667 - precision_1: 0.9691 - recall_1: 0.9649 - val_loss: 1.2612 - val_accuracy: 0.7902 - val_precision_1: 0.7953 - val_recall_1: 0.7816 - lr: 5.0000e-04
# Epoch 79/500
# 102/102 [==============================] - ETA: 0s - loss: 0.2717 - accuracy: 0.9747 - precision_1: 0.9765 - recall_1: 0.9717
# Epoch 79: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 79ms/step - loss: 0.2717 - accuracy: 0.9747 - precision_1: 0.9765 - recall_1: 0.9717 - val_loss: 1.2198 - val_accuracy: 0.7931 - val_precision_1: 0.8041 - val_recall_1: 0.7902 - lr: 5.0000e-04
# Epoch 80/500
# 102/102 [==============================] - ETA: 0s - loss: 0.2147 - accuracy: 0.9901 - precision_1: 0.9914 - recall_1: 0.9889
# Epoch 80: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 79ms/step - loss: 0.2147 - accuracy: 0.9901 - precision_1: 0.9914 - recall_1: 0.9889 - val_loss: 1.1976 - val_accuracy: 0.8132 - val_precision_1: 0.8158 - val_recall_1: 0.8017 - lr: 5.0000e-04
# Epoch 81/500
# 102/102 [==============================] - ETA: 0s - loss: 0.2227 - accuracy: 0.9858 - precision_1: 0.9870 - recall_1: 0.9840
# Epoch 81: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 79ms/step - loss: 0.2227 - accuracy: 0.9858 - precision_1: 0.9870 - recall_1: 0.9840 - val_loss: 1.1654 - val_accuracy: 0.8103 - val_precision_1: 0.8169 - val_recall_1: 0.8075 - lr: 5.0000e-04
# Epoch 82/500
# 102/102 [==============================] - ETA: 0s - loss: 0.2085 - accuracy: 0.9901 - precision_1: 0.9914 - recall_1: 0.9889
# Epoch 82: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 79ms/step - loss: 0.2085 - accuracy: 0.9901 - precision_1: 0.9914 - recall_1: 0.9889 - val_loss: 1.1316 - val_accuracy: 0.8161 - val_precision_1: 0.8251 - val_recall_1: 0.8132 - lr: 5.0000e-04
# Epoch 83/500
# 102/102 [==============================] - ETA: 0s - loss: 0.2172 - accuracy: 0.9871 - precision_1: 0.9889 - recall_1: 0.9858
# Epoch 83: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 80ms/step - loss: 0.2172 - accuracy: 0.9871 - precision_1: 0.9889 - recall_1: 0.9858 - val_loss: 1.5034 - val_accuracy: 0.7701 - val_precision_1: 0.7688 - val_recall_1: 0.7644 - lr: 5.0000e-04
# Epoch 84/500
# 102/102 [==============================] - ETA: 0s - loss: 0.2033 - accuracy: 0.9901 - precision_1: 0.9920 - recall_1: 0.9895
# Epoch 84: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 80ms/step - loss: 0.2033 - accuracy: 0.9901 - precision_1: 0.9920 - recall_1: 0.9895 - val_loss: 1.3638 - val_accuracy: 0.7902 - val_precision_1: 0.7942 - val_recall_1: 0.7874 - lr: 5.0000e-04
# Epoch 85/500
# 102/102 [==============================] - ETA: 0s - loss: 0.2177 - accuracy: 0.9858 - precision_1: 0.9877 - recall_1: 0.9858
# Epoch 85: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 81ms/step - loss: 0.2177 - accuracy: 0.9858 - precision_1: 0.9877 - recall_1: 0.9858 - val_loss: 1.4208 - val_accuracy: 0.7874 - val_precision_1: 0.7884 - val_recall_1: 0.7816 - lr: 5.0000e-04
# Epoch 86/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1933 - accuracy: 0.9877 - precision_1: 0.9883 - recall_1: 0.9877
# Epoch 86: val_loss did not improve from 1.05027
#
# Epoch 86: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 102/102 [==============================] - 8s 79ms/step - loss: 0.1933 - accuracy: 0.9877 - precision_1: 0.9883 - recall_1: 0.9877 - val_loss: 1.5544 - val_accuracy: 0.7672 - val_precision_1: 0.7717 - val_recall_1: 0.7672 - lr: 5.0000e-04
# Epoch 87/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1953 - accuracy: 0.9871 - precision_1: 0.9883 - recall_1: 0.9864
# Epoch 87: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 80ms/step - loss: 0.1953 - accuracy: 0.9871 - precision_1: 0.9883 - recall_1: 0.9864 - val_loss: 1.3168 - val_accuracy: 0.8017 - val_precision_1: 0.8134 - val_recall_1: 0.8017 - lr: 2.5000e-04
# Epoch 88/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1739 - accuracy: 0.9951 - precision_1: 0.9957 - recall_1: 0.9951
# Epoch 88: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 80ms/step - loss: 0.1739 - accuracy: 0.9951 - precision_1: 0.9957 - recall_1: 0.9951 - val_loss: 1.3302 - val_accuracy: 0.8132 - val_precision_1: 0.8156 - val_recall_1: 0.8132 - lr: 2.5000e-04
# Epoch 89/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1695 - accuracy: 0.9951 - precision_1: 0.9963 - recall_1: 0.9951
# Epoch 89: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 79ms/step - loss: 0.1695 - accuracy: 0.9951 - precision_1: 0.9963 - recall_1: 0.9951 - val_loss: 1.2576 - val_accuracy: 0.8362 - val_precision_1: 0.8392 - val_recall_1: 0.8247 - lr: 2.5000e-04
# Epoch 90/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1721 - accuracy: 0.9945 - precision_1: 0.9951 - recall_1: 0.9938
# Epoch 90: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 80ms/step - loss: 0.1721 - accuracy: 0.9945 - precision_1: 0.9951 - recall_1: 0.9938 - val_loss: 1.3274 - val_accuracy: 0.8218 - val_precision_1: 0.8218 - val_recall_1: 0.8218 - lr: 2.5000e-04
# Epoch 91/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1609 - accuracy: 0.9951 - precision_1: 0.9951 - recall_1: 0.9951
# Epoch 91: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 81ms/step - loss: 0.1609 - accuracy: 0.9951 - precision_1: 0.9951 - recall_1: 0.9951 - val_loss: 1.2595 - val_accuracy: 0.8103 - val_precision_1: 0.8169 - val_recall_1: 0.8075 - lr: 2.5000e-04
# Epoch 92/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1500 - accuracy: 0.9982 - precision_1: 0.9988 - recall_1: 0.9982
# Epoch 92: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 80ms/step - loss: 0.1500 - accuracy: 0.9982 - precision_1: 0.9988 - recall_1: 0.9982 - val_loss: 1.2984 - val_accuracy: 0.8132 - val_precision_1: 0.8150 - val_recall_1: 0.8103 - lr: 2.5000e-04
# Epoch 93/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1626 - accuracy: 0.9932 - precision_1: 0.9938 - recall_1: 0.9932
# Epoch 93: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 80ms/step - loss: 0.1626 - accuracy: 0.9932 - precision_1: 0.9938 - recall_1: 0.9932 - val_loss: 1.4235 - val_accuracy: 0.7845 - val_precision_1: 0.7867 - val_recall_1: 0.7845 - lr: 2.5000e-04
# Epoch 94/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1676 - accuracy: 0.9938 - precision_1: 0.9944 - recall_1: 0.9932
# Epoch 94: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 81ms/step - loss: 0.1676 - accuracy: 0.9938 - precision_1: 0.9944 - recall_1: 0.9932 - val_loss: 1.5301 - val_accuracy: 0.7701 - val_precision_1: 0.7701 - val_recall_1: 0.7701 - lr: 2.5000e-04
# Epoch 95/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1535 - accuracy: 0.9945 - precision_1: 0.9945 - recall_1: 0.9945
# Epoch 95: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 80ms/step - loss: 0.1535 - accuracy: 0.9945 - precision_1: 0.9945 - recall_1: 0.9945 - val_loss: 1.2748 - val_accuracy: 0.8276 - val_precision_1: 0.8319 - val_recall_1: 0.8247 - lr: 2.5000e-04
# Epoch 96/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1610 - accuracy: 0.9938 - precision_1: 0.9957 - recall_1: 0.9932
# Epoch 96: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 82ms/step - loss: 0.1610 - accuracy: 0.9938 - precision_1: 0.9957 - recall_1: 0.9932 - val_loss: 1.2324 - val_accuracy: 0.8305 - val_precision_1: 0.8353 - val_recall_1: 0.8305 - lr: 2.5000e-04
# Epoch 97/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1746 - accuracy: 0.9901 - precision_1: 0.9901 - recall_1: 0.9901
# Epoch 97: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 81ms/step - loss: 0.1746 - accuracy: 0.9901 - precision_1: 0.9901 - recall_1: 0.9901 - val_loss: 1.2879 - val_accuracy: 0.8190 - val_precision_1: 0.8227 - val_recall_1: 0.8132 - lr: 2.5000e-04
# Epoch 98/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1483 - accuracy: 0.9963 - precision_1: 0.9969 - recall_1: 0.9963
# Epoch 98: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 81ms/step - loss: 0.1483 - accuracy: 0.9963 - precision_1: 0.9969 - recall_1: 0.9963 - val_loss: 1.2648 - val_accuracy: 0.8305 - val_precision_1: 0.8305 - val_recall_1: 0.8305 - lr: 2.5000e-04
# Epoch 99/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1363 - accuracy: 0.9988 - precision_1: 0.9994 - recall_1: 0.9982
# Epoch 99: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 80ms/step - loss: 0.1363 - accuracy: 0.9988 - precision_1: 0.9994 - recall_1: 0.9982 - val_loss: 1.2019 - val_accuracy: 0.8276 - val_precision_1: 0.8300 - val_recall_1: 0.8276 - lr: 2.5000e-04
# Epoch 100/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1430 - accuracy: 0.9932 - precision_1: 0.9944 - recall_1: 0.9926
# Epoch 100: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 82ms/step - loss: 0.1430 - accuracy: 0.9932 - precision_1: 0.9944 - recall_1: 0.9926 - val_loss: 1.3654 - val_accuracy: 0.8161 - val_precision_1: 0.8179 - val_recall_1: 0.8132 - lr: 2.5000e-04
# Epoch 101/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1438 - accuracy: 0.9982 - precision_1: 0.9988 - recall_1: 0.9975
# Epoch 101: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 79ms/step - loss: 0.1438 - accuracy: 0.9982 - precision_1: 0.9988 - recall_1: 0.9975 - val_loss: 1.4103 - val_accuracy: 0.8103 - val_precision_1: 0.8145 - val_recall_1: 0.8075 - lr: 2.5000e-04
# Epoch 102/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1378 - accuracy: 0.9969 - precision_1: 0.9975 - recall_1: 0.9963
# Epoch 102: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 81ms/step - loss: 0.1378 - accuracy: 0.9969 - precision_1: 0.9975 - recall_1: 0.9963 - val_loss: 1.3180 - val_accuracy: 0.8132 - val_precision_1: 0.8203 - val_recall_1: 0.8132 - lr: 2.5000e-04
# Epoch 103/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1425 - accuracy: 0.9945 - precision_1: 0.9945 - recall_1: 0.9945
# Epoch 103: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 79ms/step - loss: 0.1425 - accuracy: 0.9945 - precision_1: 0.9945 - recall_1: 0.9945 - val_loss: 1.3172 - val_accuracy: 0.7989 - val_precision_1: 0.8000 - val_recall_1: 0.7931 - lr: 2.5000e-04
# Epoch 104/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1347 - accuracy: 0.9951 - precision_1: 0.9951 - recall_1: 0.9951
# Epoch 104: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 81ms/step - loss: 0.1347 - accuracy: 0.9951 - precision_1: 0.9951 - recall_1: 0.9951 - val_loss: 1.2892 - val_accuracy: 0.8190 - val_precision_1: 0.8237 - val_recall_1: 0.8190 - lr: 2.5000e-04
# Epoch 105/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1377 - accuracy: 0.9938 - precision_1: 0.9945 - recall_1: 0.9938
# Epoch 105: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 79ms/step - loss: 0.1377 - accuracy: 0.9938 - precision_1: 0.9945 - recall_1: 0.9938 - val_loss: 1.2750 - val_accuracy: 0.8103 - val_precision_1: 0.8145 - val_recall_1: 0.8075 - lr: 2.5000e-04
# Epoch 106/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1262 - accuracy: 0.9975 - precision_1: 0.9982 - recall_1: 0.9975
# Epoch 106: val_loss did not improve from 1.05027
#
# Epoch 106: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 102/102 [==============================] - 8s 81ms/step - loss: 0.1262 - accuracy: 0.9975 - precision_1: 0.9982 - recall_1: 0.9975 - val_loss: 1.2723 - val_accuracy: 0.8190 - val_precision_1: 0.8184 - val_recall_1: 0.8161 - lr: 2.5000e-04
# Epoch 107/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1276 - accuracy: 0.9963 - precision_1: 0.9963 - recall_1: 0.9963
# Epoch 107: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 80ms/step - loss: 0.1276 - accuracy: 0.9963 - precision_1: 0.9963 - recall_1: 0.9963 - val_loss: 1.4235 - val_accuracy: 0.7989 - val_precision_1: 0.8029 - val_recall_1: 0.7960 - lr: 1.2500e-04
# Epoch 108/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1293 - accuracy: 0.9963 - precision_1: 0.9963 - recall_1: 0.9957
# Epoch 108: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 81ms/step - loss: 0.1293 - accuracy: 0.9963 - precision_1: 0.9963 - recall_1: 0.9957 - val_loss: 1.2452 - val_accuracy: 0.8305 - val_precision_1: 0.8324 - val_recall_1: 0.8276 - lr: 1.2500e-04
# Epoch 109/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1180 - accuracy: 0.9982 - precision_1: 0.9982 - recall_1: 0.9982
# Epoch 109: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 81ms/step - loss: 0.1180 - accuracy: 0.9982 - precision_1: 0.9982 - recall_1: 0.9982 - val_loss: 1.2418 - val_accuracy: 0.8247 - val_precision_1: 0.8295 - val_recall_1: 0.8247 - lr: 1.2500e-04
# Epoch 110/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1165 - accuracy: 0.9994 - precision_1: 0.9994 - recall_1: 0.9994
# Epoch 110: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 81ms/step - loss: 0.1165 - accuracy: 0.9994 - precision_1: 0.9994 - recall_1: 0.9994 - val_loss: 1.2398 - val_accuracy: 0.8333 - val_precision_1: 0.8319 - val_recall_1: 0.8247 - lr: 1.2500e-04
# Epoch 111/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1127 - accuracy: 0.9994 - precision_1: 1.0000 - recall_1: 0.9994
# Epoch 111: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 80ms/step - loss: 0.1127 - accuracy: 0.9994 - precision_1: 1.0000 - recall_1: 0.9994 - val_loss: 1.1997 - val_accuracy: 0.8333 - val_precision_1: 0.8426 - val_recall_1: 0.8305 - lr: 1.2500e-04
# Epoch 112/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1107 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000
# Epoch 112: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 80ms/step - loss: 0.1107 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - val_loss: 1.2141 - val_accuracy: 0.8333 - val_precision_1: 0.8353 - val_recall_1: 0.8305 - lr: 1.2500e-04
# Epoch 113/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1092 - accuracy: 0.9994 - precision_1: 0.9994 - recall_1: 0.9994
# Epoch 113: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 80ms/step - loss: 0.1092 - accuracy: 0.9994 - precision_1: 0.9994 - recall_1: 0.9994 - val_loss: 1.2328 - val_accuracy: 0.8161 - val_precision_1: 0.8256 - val_recall_1: 0.8161 - lr: 1.2500e-04
# Epoch 114/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1077 - accuracy: 0.9994 - precision_1: 0.9994 - recall_1: 0.9988
# Epoch 114: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 81ms/step - loss: 0.1077 - accuracy: 0.9994 - precision_1: 0.9994 - recall_1: 0.9988 - val_loss: 1.2402 - val_accuracy: 0.8333 - val_precision_1: 0.8348 - val_recall_1: 0.8276 - lr: 1.2500e-04
# Epoch 115/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1065 - accuracy: 0.9994 - precision_1: 0.9994 - recall_1: 0.9994
# Epoch 115: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 79ms/step - loss: 0.1065 - accuracy: 0.9994 - precision_1: 0.9994 - recall_1: 0.9994 - val_loss: 1.2966 - val_accuracy: 0.8132 - val_precision_1: 0.8179 - val_recall_1: 0.8132 - lr: 1.2500e-04
# Epoch 116/500
# 102/102 [==============================] - ETA: 0s - loss: 0.1152 - accuracy: 0.9969 - precision_1: 0.9969 - recall_1: 0.9969Restoring model weights from the end of the best epoch: 66.
#
# Epoch 116: val_loss did not improve from 1.05027
# 102/102 [==============================] - 8s 81ms/step - loss: 0.1152 - accuracy: 0.9969 - precision_1: 0.9969 - recall_1: 0.9969 - val_loss: 1.3654 - val_accuracy: 0.8132 - val_precision_1: 0.8174 - val_recall_1: 0.8103 - lr: 1.2500e-04
# Epoch 116: early stopping
# 11/11 [==============================] - 0s 13ms/step - loss: 1.0615 - accuracy: 0.8218 - precision_1: 0.8324 - recall_1: 0.8132
# Test Loss: 1.0615
# Test Accuracy: 0.8218
# Test Precision: 0.8324
# Test Recall: 0.8132
# 11/11 [==============================] - 0s 12ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.81      0.84      0.83        45
#         calm       0.91      0.91      0.91        47
#      disgust       0.78      0.83      0.80        46
#      fearful       0.85      0.81      0.83        48
#        happy       0.74      0.67      0.70        46
#      neutral       0.85      1.00      0.92        22
#          sad       0.72      0.72      0.72        47
#    surprised       0.93      0.87      0.90        47
#
#     accuracy                           0.82       348
#    macro avg       0.82      0.83      0.83       348
# weighted avg       0.82      0.82      0.82       348
