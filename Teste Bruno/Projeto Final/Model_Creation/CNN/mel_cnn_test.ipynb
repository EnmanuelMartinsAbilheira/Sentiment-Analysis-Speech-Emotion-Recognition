# %%
# ! pip install tensorflow-directml-plugin
# ! pip install librosa
# ! pip uninstall numpy
# ! pip install numpy==1.26.4

# %%
import os
import glob
import numpy as np
import librosa
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

# %%
def extract_label(file_path):
    """
    Extracts the sentiment label from the penultimate letter of the filename.
    Expected mapping:
        E - disgust
        L - boredom
        W - anger	
        A - anxiety
        F - happiness
        T - sadness
        N - neutral
    """
    filename = os.path.basename(file_path)
    name_without_ext = os.path.splitext(filename)[0]
    if len(name_without_ext) < 2:
        raise ValueError(f"Filename '{filename}' is too short to extract label.")
    # Get the penultimate character and convert to uppercase
    penultimate = name_without_ext[-2].upper()
    mapping = {
        'E': 'disgust',
        'L': 'boredom',
        'W': 'anger',
        'A': 'anxiety',
        'F': 'happiness',
        'T': 'sadness',
        'N': 'neutral'
    }
    label = mapping.get(penultimate, 'unknown')
    if label == 'unknown':
        print(f"Warning: Unknown sentiment for file {filename} with letter '{penultimate}'")
    return label

# %%
def load_data(dataset_path, sr=22050, duration=3, n_mels=128):
    """
    Loads WAV files from the given directory, converts each to a mel-spectrogram,
    and extracts labels based on the filename.
    
    Parameters:
      - dataset_path: path to the directory containing .wav files
      - sr: sampling rate for audio files
      - duration: duration (in seconds) to which each audio file will be trimmed or padded
      - n_mels: number of mel bands for the spectrogram
    
    Returns:
      - X: numpy array of mel-spectrograms
      - y: numpy array of sentiment labels
    """
    X = []
    y = []
    files = glob.glob(os.path.join(dataset_path, '*.wav'))
    print(f"Found {len(files)} audio files.")
    for file in files:
        try:
            label = extract_label(file)
            # Load audio file (if the file is shorter than the duration, it will be padded)
            audio, _ = librosa.load(file, sr=sr, duration=duration)
            if len(audio) < sr * duration:
                padding = sr * duration - len(audio)
                audio = np.pad(audio, (0, padding), 'constant')
            # Compute the mel-spectrogram
            mel_spec = librosa.feature.melspectrogram(y=audio, sr=sr, n_mels=n_mels)
            # Convert to log scale (dB)
            mel_spec = librosa.power_to_db(mel_spec, ref=np.max)
            X.append(mel_spec)
            y.append(label)
        except Exception as e:
            print(f"Error processing {file}: {e}")
    X = np.array(X)
    y = np.array(y)
    return X, y

# %%
def preprocess_labels(y):
    """
    Encodes string labels into numerical one-hot vectors.
    """
    le = LabelEncoder()
    y_encoded = le.fit_transform(y)
    y_onehot = to_categorical(y_encoded)
    return y_onehot, le

# %%
def build_model(input_shape, num_classes):
    """
    Builds and returns an improved CNN model using Keras with better architecture
    for increased accuracy.
    """
    model = Sequential()
    
    # First convolutional block - increased filters and added batch normalization
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu', input_shape=input_shape))
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.2))
    
    # Second convolutional block with more filters
    model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.3))
    
    # Third convolutional block for deeper feature extraction
    model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.4))
    
    # Fully connected layers
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    
    return model

# %%
def scheduler(epoch, lr):
    # reduce learning rate by half every 10 epochs
    if epoch > 0 and epoch % 100 == 0:
        return lr * 0.5
    return lr

# %%
def main():
    dataset_path = 'EmoDB\wav'  # Update with your dataset path
    X, y = load_data(dataset_path)
    print("Shape before expanding dims:", X.shape)
    # Expand dims to add a channel dimension for CNN input
    X = X[..., np.newaxis]
    print("Shape after expanding dims:", X.shape)
    
    y_onehot, le = preprocess_labels(y)
    print("Detected labels:", le.classes_)
    
    # Stratified and shuffled train-test split
    X_train, X_val, y_train, y_val = train_test_split(
        X, y_onehot, test_size=0.2, random_state=42, shuffle=True, 
        stratify=np.argmax(y_onehot, axis=1)
    )
    
    input_shape = X_train.shape[1:]
    num_classes = y_onehot.shape[1]
    model = build_model(input_shape, num_classes)
    
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    model.summary()
    
    # Define callbacks
    early_stop = EarlyStopping(monitor='val_loss', patience=200, restore_best_weights=True)
    lr_scheduler = LearningRateScheduler(scheduler)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=100, min_lr=1e-6)
    
    epochs = 2000
    batch_size = 32
    history = model.fit(
        X_train, y_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(X_val, y_val),
        callbacks=[early_stop, lr_scheduler, reduce_lr]
    )
    
    loss, acc = model.evaluate(X_val, y_val)
    print(f"Validation Loss: {loss:.4f}, Validation Accuracy: {acc:.4f}")
    
    # model.save('sentiment_cnn_model.h5')
    # print("Model saved as 'sentiment_cnn_model.h5'")

# %%
if __name__ == '__main__':
    main()
# Out:
# Found 535 audio files.
# Shape before expanding dims: (535, 128, 130)
# Shape after expanding dims: (535, 128, 130, 1)
# Detected labels: ['anger' 'anxiety' 'boredom' 'disgust' 'happiness' 'neutral' 'sadness']
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 130, 16)      160
#
#  batch_normalization (BatchN  (None, 128, 130, 16)     64
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 64, 65, 16)       0
#  )
#
#  dropout (Dropout)           (None, 64, 65, 16)        0
#
#  conv2d_1 (Conv2D)           (None, 64, 65, 32)        4640
#
#  batch_normalization_1 (Batc  (None, 64, 65, 32)       128
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 32, 32, 32)        0
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 64)                2097216
#
#  batch_normalization_2 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 2,102,919
# Trainable params: 2,102,695
# Non-trainable params: 224
# _________________________________________________________________
# Epoch 1/2000
# 14/14 [==============================] - 1s 26ms/step - loss: 2.0371 - accuracy: 0.3341 - val_loss: 14.9469 - val_accuracy: 0.1308 - lr: 0.0010
# Epoch 2/2000
# 14/14 [==============================] - 0s 12ms/step - loss: 1.0491 - accuracy: 0.6168 - val_loss: 10.6581 - val_accuracy: 0.1308 - lr: 0.0010
# Epoch 3/2000
# 14/14 [==============================] - 0s 12ms/step - loss: 0.7597 - accuracy: 0.7453 - val_loss: 5.7414 - val_accuracy: 0.1308 - lr: 0.0010
# Epoch 4/2000
# 14/14 [==============================] - 0s 12ms/step - loss: 0.5735 - accuracy: 0.8154 - val_loss: 4.7964 - val_accuracy: 0.1308 - lr: 0.0010
# Epoch 5/2000
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4245 - accuracy: 0.8762 - val_loss: 3.2718 - val_accuracy: 0.2243 - lr: 0.0010
# Epoch 6/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.3528 - accuracy: 0.9042 - val_loss: 3.3999 - val_accuracy: 0.1589 - lr: 0.0010
# Epoch 7/2000
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3002 - accuracy: 0.9252 - val_loss: 2.1412 - val_accuracy: 0.3178 - lr: 0.0010
# Epoch 8/2000
# 14/14 [==============================] - 0s 12ms/step - loss: 0.2319 - accuracy: 0.9556 - val_loss: 1.6113 - val_accuracy: 0.4112 - lr: 0.0010
# Epoch 9/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.2270 - accuracy: 0.9486 - val_loss: 1.6277 - val_accuracy: 0.4766 - lr: 0.0010
# Epoch 10/2000
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1744 - accuracy: 0.9696 - val_loss: 1.4201 - val_accuracy: 0.5140 - lr: 0.0010
# Epoch 11/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1428 - accuracy: 0.9743 - val_loss: 1.3887 - val_accuracy: 0.4860 - lr: 0.0010
# Epoch 12/2000
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1473 - accuracy: 0.9673 - val_loss: 1.5446 - val_accuracy: 0.5327 - lr: 0.0010
# Epoch 13/2000
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1199 - accuracy: 0.9860 - val_loss: 1.4091 - val_accuracy: 0.5421 - lr: 0.0010
# Epoch 14/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1114 - accuracy: 0.9860 - val_loss: 1.8387 - val_accuracy: 0.3832 - lr: 0.0010
# Epoch 15/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1026 - accuracy: 0.9813 - val_loss: 2.2387 - val_accuracy: 0.3178 - lr: 0.0010
# Epoch 16/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1009 - accuracy: 0.9836 - val_loss: 2.6055 - val_accuracy: 0.2710 - lr: 0.0010
# Epoch 17/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0892 - accuracy: 0.9860 - val_loss: 2.9865 - val_accuracy: 0.2430 - lr: 0.0010
# Epoch 18/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0775 - accuracy: 0.9977 - val_loss: 1.9114 - val_accuracy: 0.4486 - lr: 0.0010
# Epoch 19/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0699 - accuracy: 0.9977 - val_loss: 1.7126 - val_accuracy: 0.5514 - lr: 0.0010
# Epoch 20/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0722 - accuracy: 0.9953 - val_loss: 2.0781 - val_accuracy: 0.4019 - lr: 0.0010
# Epoch 21/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0682 - accuracy: 0.9930 - val_loss: 1.7151 - val_accuracy: 0.5234 - lr: 0.0010
# Epoch 22/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0666 - accuracy: 0.9930 - val_loss: 1.6762 - val_accuracy: 0.4860 - lr: 0.0010
# Epoch 23/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0522 - accuracy: 1.0000 - val_loss: 2.2019 - val_accuracy: 0.3364 - lr: 0.0010
# Epoch 24/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0533 - accuracy: 0.9930 - val_loss: 2.0939 - val_accuracy: 0.3738 - lr: 0.0010
# Epoch 25/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0366 - accuracy: 1.0000 - val_loss: 1.8884 - val_accuracy: 0.4112 - lr: 0.0010
# Epoch 26/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0381 - accuracy: 1.0000 - val_loss: 2.3971 - val_accuracy: 0.3364 - lr: 0.0010
# Epoch 27/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0393 - accuracy: 0.9930 - val_loss: 1.7886 - val_accuracy: 0.4860 - lr: 0.0010
# Epoch 28/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0373 - accuracy: 0.9977 - val_loss: 1.6838 - val_accuracy: 0.5514 - lr: 0.0010
# Epoch 29/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0414 - accuracy: 1.0000 - val_loss: 2.0969 - val_accuracy: 0.4299 - lr: 0.0010
# Epoch 30/2000
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0295 - accuracy: 1.0000 - val_loss: 2.0462 - val_accuracy: 0.4393 - lr: 0.0010
# Epoch 31/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0299 - accuracy: 0.9977 - val_loss: 2.3928 - val_accuracy: 0.3832 - lr: 0.0010
# Epoch 32/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0228 - accuracy: 0.9977 - val_loss: 2.3429 - val_accuracy: 0.3925 - lr: 0.0010
# Epoch 33/2000
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0328 - accuracy: 0.9977 - val_loss: 3.0930 - val_accuracy: 0.2991 - lr: 0.0010
# Epoch 34/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0303 - accuracy: 1.0000 - val_loss: 2.2332 - val_accuracy: 0.4579 - lr: 0.0010
# Epoch 35/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0364 - accuracy: 0.9953 - val_loss: 2.3972 - val_accuracy: 0.4579 - lr: 0.0010
# Epoch 36/2000
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0297 - accuracy: 1.0000 - val_loss: 1.8900 - val_accuracy: 0.5234 - lr: 0.0010
# Epoch 37/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0313 - accuracy: 1.0000 - val_loss: 1.5001 - val_accuracy: 0.5794 - lr: 0.0010
# Epoch 38/2000
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0296 - accuracy: 1.0000 - val_loss: 2.4967 - val_accuracy: 0.3364 - lr: 0.0010
# Epoch 39/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0263 - accuracy: 0.9977 - val_loss: 2.5761 - val_accuracy: 0.3645 - lr: 0.0010
# Epoch 40/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0221 - accuracy: 1.0000 - val_loss: 1.5407 - val_accuracy: 0.5794 - lr: 0.0010
# Epoch 41/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0200 - accuracy: 1.0000 - val_loss: 1.7201 - val_accuracy: 0.5421 - lr: 0.0010
# Epoch 42/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0242 - accuracy: 0.9977 - val_loss: 2.2338 - val_accuracy: 0.4112 - lr: 0.0010
# Epoch 43/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0226 - accuracy: 0.9977 - val_loss: 2.4853 - val_accuracy: 0.4206 - lr: 0.0010
# Epoch 44/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0254 - accuracy: 0.9977 - val_loss: 1.4332 - val_accuracy: 0.5514 - lr: 0.0010
# Epoch 45/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0225 - accuracy: 1.0000 - val_loss: 1.4637 - val_accuracy: 0.6262 - lr: 0.0010
# Epoch 46/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0283 - accuracy: 0.9930 - val_loss: 2.0845 - val_accuracy: 0.4766 - lr: 0.0010
# Epoch 47/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0202 - accuracy: 0.9977 - val_loss: 1.7210 - val_accuracy: 0.5047 - lr: 0.0010
# Epoch 48/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0239 - accuracy: 0.9953 - val_loss: 1.8081 - val_accuracy: 0.4766 - lr: 0.0010
# Epoch 49/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 1.7841 - val_accuracy: 0.4860 - lr: 0.0010
# Epoch 50/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0192 - accuracy: 0.9977 - val_loss: 1.8847 - val_accuracy: 0.4673 - lr: 0.0010
# Epoch 51/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 1.5088 - val_accuracy: 0.5140 - lr: 0.0010
# Epoch 52/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 1.6606 - val_accuracy: 0.5047 - lr: 0.0010
# Epoch 53/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0202 - accuracy: 0.9977 - val_loss: 1.9035 - val_accuracy: 0.5047 - lr: 0.0010
# Epoch 54/2000
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 1.4955 - val_accuracy: 0.5421 - lr: 0.0010
# Epoch 55/2000
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 1.3882 - val_accuracy: 0.5888 - lr: 0.0010
# Epoch 56/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 1.4791 - val_accuracy: 0.5607 - lr: 0.0010
# Epoch 57/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 2.3724 - val_accuracy: 0.4953 - lr: 0.0010
# Epoch 58/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0179 - accuracy: 0.9977 - val_loss: 1.9239 - val_accuracy: 0.4953 - lr: 0.0010
# Epoch 59/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 1.1934 - val_accuracy: 0.6542 - lr: 0.0010
# Epoch 60/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 1.1252 - val_accuracy: 0.6636 - lr: 0.0010
# Epoch 61/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0178 - accuracy: 0.9977 - val_loss: 1.5468 - val_accuracy: 0.5607 - lr: 0.0010
# Epoch 62/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 1.4722 - val_accuracy: 0.5794 - lr: 0.0010
# Epoch 63/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 1.7966 - val_accuracy: 0.5514 - lr: 0.0010
# Epoch 64/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0171 - accuracy: 0.9977 - val_loss: 1.6151 - val_accuracy: 0.5514 - lr: 0.0010
# Epoch 65/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0151 - accuracy: 0.9977 - val_loss: 1.5304 - val_accuracy: 0.5794 - lr: 0.0010
# Epoch 66/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 1.5186 - val_accuracy: 0.5327 - lr: 0.0010
# Epoch 67/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0187 - accuracy: 0.9953 - val_loss: 1.8425 - val_accuracy: 0.5140 - lr: 0.0010
# Epoch 68/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0186 - accuracy: 0.9977 - val_loss: 2.4595 - val_accuracy: 0.4299 - lr: 0.0010
# Epoch 69/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0204 - accuracy: 0.9977 - val_loss: 1.5969 - val_accuracy: 0.5701 - lr: 0.0010
# Epoch 70/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 1.7441 - val_accuracy: 0.5327 - lr: 0.0010
# Epoch 71/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 1.6988 - val_accuracy: 0.5514 - lr: 0.0010
# Epoch 72/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0127 - accuracy: 0.9977 - val_loss: 1.9318 - val_accuracy: 0.5047 - lr: 0.0010
# Epoch 73/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 1.7140 - val_accuracy: 0.5327 - lr: 0.0010
# Epoch 74/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0138 - accuracy: 0.9977 - val_loss: 1.5722 - val_accuracy: 0.5607 - lr: 0.0010
# Epoch 75/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 1.5248 - val_accuracy: 0.5607 - lr: 0.0010
# Epoch 76/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0119 - accuracy: 0.9977 - val_loss: 1.6362 - val_accuracy: 0.5140 - lr: 0.0010
# Epoch 77/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 1.3560 - val_accuracy: 0.6075 - lr: 0.0010
# Epoch 78/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 1.2659 - val_accuracy: 0.6636 - lr: 0.0010
# Epoch 79/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 1.4965 - val_accuracy: 0.5607 - lr: 0.0010
# Epoch 80/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 1.6322 - val_accuracy: 0.5327 - lr: 0.0010
# Epoch 81/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 1.5655 - val_accuracy: 0.5514 - lr: 0.0010
# Epoch 82/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0135 - accuracy: 0.9977 - val_loss: 1.8370 - val_accuracy: 0.5421 - lr: 0.0010
# Epoch 83/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0099 - accuracy: 0.9977 - val_loss: 1.7739 - val_accuracy: 0.5701 - lr: 0.0010
# Epoch 84/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 1.7693 - val_accuracy: 0.5701 - lr: 0.0010
# Epoch 85/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 2.1761 - val_accuracy: 0.4953 - lr: 0.0010
# Epoch 86/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 1.8255 - val_accuracy: 0.5327 - lr: 0.0010
# Epoch 87/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 1.7692 - val_accuracy: 0.5234 - lr: 0.0010
# Epoch 88/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 1.7682 - val_accuracy: 0.5234 - lr: 0.0010
# Epoch 89/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0085 - accuracy: 0.9977 - val_loss: 1.4659 - val_accuracy: 0.5981 - lr: 0.0010
# Epoch 90/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 1.2369 - val_accuracy: 0.6542 - lr: 0.0010
# Epoch 91/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 1.4278 - val_accuracy: 0.6262 - lr: 0.0010
# Epoch 92/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 1.5313 - val_accuracy: 0.5514 - lr: 0.0010
# Epoch 93/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.6230 - val_accuracy: 0.5701 - lr: 0.0010
# Epoch 94/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 1.5754 - val_accuracy: 0.5701 - lr: 0.0010
# Epoch 95/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0116 - accuracy: 0.9977 - val_loss: 1.2041 - val_accuracy: 0.7009 - lr: 0.0010
# Epoch 96/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 1.2669 - val_accuracy: 0.6822 - lr: 0.0010
# Epoch 97/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.1866 - val_accuracy: 0.6729 - lr: 0.0010
# Epoch 98/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 1.4058 - val_accuracy: 0.5981 - lr: 0.0010
# Epoch 99/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.3244 - val_accuracy: 0.5981 - lr: 0.0010
# Epoch 100/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.2389 - val_accuracy: 0.6168 - lr: 0.0010
# Epoch 101/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.2575 - val_accuracy: 0.6075 - lr: 5.0000e-04
# Epoch 102/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.2570 - val_accuracy: 0.6075 - lr: 5.0000e-04
# Epoch 103/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 1.2051 - val_accuracy: 0.6636 - lr: 5.0000e-04
# Epoch 104/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 1.2402 - val_accuracy: 0.6542 - lr: 5.0000e-04
# Epoch 105/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.4114 - val_accuracy: 0.6075 - lr: 5.0000e-04
# Epoch 106/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 1.4557 - val_accuracy: 0.6075 - lr: 5.0000e-04
# Epoch 107/2000
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 1.4336 - val_accuracy: 0.6262 - lr: 5.0000e-04
# Epoch 108/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 1.3916 - val_accuracy: 0.6262 - lr: 5.0000e-04
# Epoch 109/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.3298 - val_accuracy: 0.6168 - lr: 5.0000e-04
# Epoch 110/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 1.3943 - val_accuracy: 0.6262 - lr: 5.0000e-04
# Epoch 111/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0075 - accuracy: 0.9977 - val_loss: 1.5085 - val_accuracy: 0.6262 - lr: 5.0000e-04
# Epoch 112/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.5198 - val_accuracy: 0.6262 - lr: 5.0000e-04
# Epoch 113/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.4374 - val_accuracy: 0.6262 - lr: 5.0000e-04
# Epoch 114/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 1.3898 - val_accuracy: 0.5888 - lr: 5.0000e-04
# Epoch 115/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 1.2814 - val_accuracy: 0.6168 - lr: 5.0000e-04
# Epoch 116/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.3474 - val_accuracy: 0.6168 - lr: 5.0000e-04
# Epoch 117/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.4280 - val_accuracy: 0.6075 - lr: 5.0000e-04
# Epoch 118/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.4285 - val_accuracy: 0.6075 - lr: 5.0000e-04
# Epoch 119/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.4099 - val_accuracy: 0.6075 - lr: 5.0000e-04
# Epoch 120/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.2616 - val_accuracy: 0.6355 - lr: 5.0000e-04
# Epoch 121/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 1.2874 - val_accuracy: 0.6168 - lr: 5.0000e-04
# Epoch 122/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.2889 - val_accuracy: 0.6262 - lr: 5.0000e-04
# Epoch 123/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.3191 - val_accuracy: 0.6262 - lr: 5.0000e-04
# Epoch 124/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.3982 - val_accuracy: 0.6168 - lr: 5.0000e-04
# Epoch 125/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0067 - accuracy: 0.9977 - val_loss: 1.3841 - val_accuracy: 0.6168 - lr: 5.0000e-04
# Epoch 126/2000
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.4153 - val_accuracy: 0.6075 - lr: 5.0000e-04
# Epoch 127/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.3618 - val_accuracy: 0.6262 - lr: 5.0000e-04
# Epoch 128/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.3260 - val_accuracy: 0.6262 - lr: 5.0000e-04
# Epoch 129/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 1.4067 - val_accuracy: 0.6168 - lr: 5.0000e-04
# Epoch 130/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 1.5952 - val_accuracy: 0.5607 - lr: 5.0000e-04
# Epoch 131/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.8322 - val_accuracy: 0.4953 - lr: 5.0000e-04
# Epoch 132/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.4053 - val_accuracy: 0.5981 - lr: 5.0000e-04
# Epoch 133/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0053 - accuracy: 0.9977 - val_loss: 1.2513 - val_accuracy: 0.6449 - lr: 5.0000e-04
# Epoch 134/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.2852 - val_accuracy: 0.6262 - lr: 5.0000e-04
# Epoch 135/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.3551 - val_accuracy: 0.6168 - lr: 5.0000e-04
# Epoch 136/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.6443 - val_accuracy: 0.5514 - lr: 5.0000e-04
# Epoch 137/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 1.6735 - val_accuracy: 0.5607 - lr: 5.0000e-04
# Epoch 138/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.5157 - val_accuracy: 0.5794 - lr: 5.0000e-04
# Epoch 139/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.5078 - val_accuracy: 0.5888 - lr: 5.0000e-04
# Epoch 140/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.6134 - val_accuracy: 0.5701 - lr: 5.0000e-04
# Epoch 141/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0060 - accuracy: 0.9977 - val_loss: 1.3654 - val_accuracy: 0.5981 - lr: 5.0000e-04
# Epoch 142/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 1.3025 - val_accuracy: 0.6542 - lr: 5.0000e-04
# Epoch 143/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 1.4005 - val_accuracy: 0.6168 - lr: 5.0000e-04
# Epoch 144/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.5580 - val_accuracy: 0.6168 - lr: 5.0000e-04
# Epoch 145/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.6243 - val_accuracy: 0.6075 - lr: 5.0000e-04
# Epoch 146/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 1.6505 - val_accuracy: 0.5888 - lr: 5.0000e-04
# Epoch 147/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.6946 - val_accuracy: 0.5701 - lr: 5.0000e-04
# Epoch 148/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.5480 - val_accuracy: 0.5888 - lr: 5.0000e-04
# Epoch 149/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.5183 - val_accuracy: 0.5888 - lr: 5.0000e-04
# Epoch 150/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.5163 - val_accuracy: 0.5888 - lr: 5.0000e-04
# Epoch 151/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 1.4255 - val_accuracy: 0.6075 - lr: 5.0000e-04
# Epoch 152/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.3692 - val_accuracy: 0.6449 - lr: 5.0000e-04
# Epoch 153/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.4393 - val_accuracy: 0.5981 - lr: 5.0000e-04
# Epoch 154/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.4392 - val_accuracy: 0.5981 - lr: 5.0000e-04
# Epoch 155/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.4523 - val_accuracy: 0.5981 - lr: 5.0000e-04
# Epoch 156/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.3968 - val_accuracy: 0.6075 - lr: 5.0000e-04
# Epoch 157/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.3773 - val_accuracy: 0.5981 - lr: 5.0000e-04
# Epoch 158/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.5288 - val_accuracy: 0.6075 - lr: 5.0000e-04
# Epoch 159/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.6246 - val_accuracy: 0.5794 - lr: 5.0000e-04
# Epoch 160/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.4263 - val_accuracy: 0.6355 - lr: 5.0000e-04
# Epoch 161/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.4353 - val_accuracy: 0.6449 - lr: 2.5000e-04
# Epoch 162/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.3601 - val_accuracy: 0.6355 - lr: 2.5000e-04
# Epoch 163/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.3610 - val_accuracy: 0.6355 - lr: 2.5000e-04
# Epoch 164/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.3938 - val_accuracy: 0.6355 - lr: 2.5000e-04
# Epoch 165/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 1.4098 - val_accuracy: 0.6168 - lr: 2.5000e-04
# Epoch 166/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.4514 - val_accuracy: 0.6262 - lr: 2.5000e-04
# Epoch 167/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.3901 - val_accuracy: 0.6355 - lr: 2.5000e-04
# Epoch 168/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.3762 - val_accuracy: 0.6449 - lr: 2.5000e-04
# Epoch 169/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.3784 - val_accuracy: 0.6542 - lr: 2.5000e-04
# Epoch 170/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.3791 - val_accuracy: 0.6355 - lr: 2.5000e-04
# Epoch 171/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.4507 - val_accuracy: 0.6168 - lr: 2.5000e-04
# Epoch 172/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.7746 - val_accuracy: 0.5140 - lr: 2.5000e-04
# Epoch 173/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.7176 - val_accuracy: 0.5327 - lr: 2.5000e-04
# Epoch 174/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 1.6085 - val_accuracy: 0.5514 - lr: 2.5000e-04
# Epoch 175/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.4717 - val_accuracy: 0.6168 - lr: 2.5000e-04
# Epoch 176/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.4611 - val_accuracy: 0.6168 - lr: 2.5000e-04
# Epoch 177/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.5409 - val_accuracy: 0.5701 - lr: 2.5000e-04
# Epoch 178/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.5351 - val_accuracy: 0.5607 - lr: 2.5000e-04
# Epoch 179/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.4657 - val_accuracy: 0.5981 - lr: 2.5000e-04
# Epoch 180/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.3350 - val_accuracy: 0.6355 - lr: 2.5000e-04
# Epoch 181/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.2662 - val_accuracy: 0.6729 - lr: 2.5000e-04
# Epoch 182/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.2765 - val_accuracy: 0.6822 - lr: 2.5000e-04
# Epoch 183/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.2817 - val_accuracy: 0.6729 - lr: 2.5000e-04
# Epoch 184/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.2948 - val_accuracy: 0.6729 - lr: 2.5000e-04
# Epoch 185/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.3122 - val_accuracy: 0.6636 - lr: 2.5000e-04
# Epoch 186/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.2841 - val_accuracy: 0.6355 - lr: 2.5000e-04
# Epoch 187/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.2907 - val_accuracy: 0.6542 - lr: 2.5000e-04
# Epoch 188/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.3109 - val_accuracy: 0.6355 - lr: 2.5000e-04
# Epoch 189/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.3737 - val_accuracy: 0.6168 - lr: 2.5000e-04
# Epoch 190/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.3555 - val_accuracy: 0.6262 - lr: 2.5000e-04
# Epoch 191/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.3630 - val_accuracy: 0.6542 - lr: 2.5000e-04
# Epoch 192/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.3808 - val_accuracy: 0.6355 - lr: 2.5000e-04
# Epoch 193/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.3836 - val_accuracy: 0.6355 - lr: 2.5000e-04
# Epoch 194/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.3916 - val_accuracy: 0.6075 - lr: 2.5000e-04
# Epoch 195/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.4006 - val_accuracy: 0.6075 - lr: 2.5000e-04
# Epoch 196/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.4090 - val_accuracy: 0.6075 - lr: 2.5000e-04
# Epoch 197/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.4168 - val_accuracy: 0.5888 - lr: 2.5000e-04
# Epoch 198/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.4392 - val_accuracy: 0.5981 - lr: 2.5000e-04
# Epoch 199/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.4030 - val_accuracy: 0.5981 - lr: 2.5000e-04
# Epoch 200/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.3801 - val_accuracy: 0.6075 - lr: 2.5000e-04
# Epoch 201/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 1.3803 - val_accuracy: 0.6075 - lr: 1.2500e-04
# Epoch 202/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.3707 - val_accuracy: 0.6075 - lr: 1.2500e-04
# Epoch 203/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.3775 - val_accuracy: 0.6168 - lr: 1.2500e-04
# Epoch 204/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.3731 - val_accuracy: 0.6168 - lr: 1.2500e-04
# Epoch 205/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.3783 - val_accuracy: 0.6168 - lr: 1.2500e-04
# Epoch 206/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.3747 - val_accuracy: 0.6075 - lr: 1.2500e-04
# Epoch 207/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.3967 - val_accuracy: 0.6168 - lr: 1.2500e-04
# Epoch 208/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.3979 - val_accuracy: 0.6168 - lr: 1.2500e-04
# Epoch 209/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.3835 - val_accuracy: 0.6168 - lr: 1.2500e-04
# Epoch 210/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.3771 - val_accuracy: 0.6168 - lr: 1.2500e-04
# Epoch 211/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.3722 - val_accuracy: 0.6168 - lr: 1.2500e-04
# Epoch 212/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.3718 - val_accuracy: 0.6168 - lr: 1.2500e-04
# Epoch 213/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.3794 - val_accuracy: 0.6168 - lr: 1.2500e-04
# Epoch 214/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.3768 - val_accuracy: 0.6262 - lr: 1.2500e-04
# Epoch 215/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.3483 - val_accuracy: 0.6355 - lr: 1.2500e-04
# Epoch 216/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.3565 - val_accuracy: 0.6262 - lr: 1.2500e-04
# Epoch 217/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.3647 - val_accuracy: 0.6262 - lr: 1.2500e-04
# Epoch 218/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.3576 - val_accuracy: 0.6355 - lr: 1.2500e-04
# Epoch 219/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0049 - accuracy: 0.9977 - val_loss: 1.3691 - val_accuracy: 0.6355 - lr: 1.2500e-04
# Epoch 220/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.4713 - val_accuracy: 0.6355 - lr: 1.2500e-04
# Epoch 221/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.4627 - val_accuracy: 0.6262 - lr: 1.2500e-04
# Epoch 222/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.4553 - val_accuracy: 0.6355 - lr: 1.2500e-04
# Epoch 223/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.4617 - val_accuracy: 0.6262 - lr: 1.2500e-04
# Epoch 224/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.4158 - val_accuracy: 0.6355 - lr: 1.2500e-04
# Epoch 225/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.4759 - val_accuracy: 0.6168 - lr: 1.2500e-04
# Epoch 226/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.7855 - val_accuracy: 0.5701 - lr: 1.2500e-04
# Epoch 227/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.7819 - val_accuracy: 0.5701 - lr: 1.2500e-04
# Epoch 228/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 9.2208e-04 - accuracy: 1.0000 - val_loss: 1.7641 - val_accuracy: 0.5794 - lr: 1.2500e-04
# Epoch 229/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.5546 - val_accuracy: 0.6075 - lr: 1.2500e-04
# Epoch 230/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.4722 - val_accuracy: 0.6168 - lr: 1.2500e-04
# Epoch 231/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.4650 - val_accuracy: 0.6355 - lr: 1.2500e-04
# Epoch 232/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.4436 - val_accuracy: 0.6168 - lr: 1.2500e-04
# Epoch 233/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.4041 - val_accuracy: 0.6262 - lr: 1.2500e-04
# Epoch 234/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.3479 - val_accuracy: 0.6355 - lr: 1.2500e-04
# Epoch 235/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.3221 - val_accuracy: 0.6729 - lr: 1.2500e-04
# Epoch 236/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.3189 - val_accuracy: 0.6449 - lr: 1.2500e-04
# Epoch 237/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.3371 - val_accuracy: 0.6355 - lr: 1.2500e-04
# Epoch 238/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.3473 - val_accuracy: 0.6262 - lr: 1.2500e-04
# Epoch 239/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.3615 - val_accuracy: 0.6262 - lr: 1.2500e-04
# Epoch 240/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.3284 - val_accuracy: 0.6449 - lr: 1.2500e-04
# Epoch 241/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.3161 - val_accuracy: 0.6542 - lr: 1.2500e-04
# Epoch 242/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.3099 - val_accuracy: 0.6542 - lr: 1.2500e-04
# Epoch 243/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.3138 - val_accuracy: 0.6542 - lr: 1.2500e-04
# Epoch 244/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.2913 - val_accuracy: 0.6449 - lr: 1.2500e-04
# Epoch 245/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.2852 - val_accuracy: 0.6729 - lr: 1.2500e-04
# Epoch 246/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.2940 - val_accuracy: 0.6355 - lr: 1.2500e-04
# Epoch 247/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.3071 - val_accuracy: 0.6168 - lr: 1.2500e-04
# Epoch 248/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.3205 - val_accuracy: 0.6168 - lr: 1.2500e-04
# Epoch 249/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.3248 - val_accuracy: 0.6075 - lr: 1.2500e-04
# Epoch 250/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.3198 - val_accuracy: 0.6075 - lr: 1.2500e-04
# Epoch 251/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0038 - accuracy: 0.9977 - val_loss: 1.3855 - val_accuracy: 0.6262 - lr: 1.2500e-04
# Epoch 252/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.4770 - val_accuracy: 0.5888 - lr: 1.2500e-04
# Epoch 253/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.4633 - val_accuracy: 0.6075 - lr: 1.2500e-04
# Epoch 254/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.4452 - val_accuracy: 0.6075 - lr: 1.2500e-04
# Epoch 255/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.4239 - val_accuracy: 0.6262 - lr: 1.2500e-04
# Epoch 256/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.4540 - val_accuracy: 0.6262 - lr: 1.2500e-04
# Epoch 257/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.4251 - val_accuracy: 0.6355 - lr: 1.2500e-04
# Epoch 258/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.4153 - val_accuracy: 0.6262 - lr: 1.2500e-04
# Epoch 259/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.4274 - val_accuracy: 0.6168 - lr: 1.2500e-04
# Epoch 260/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.4284 - val_accuracy: 0.6168 - lr: 1.2500e-04
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1252 - accuracy: 0.6636
# Validation Loss: 1.1252, Validation Accuracy: 0.6636
