# %%
import os
import glob
import numpy as np
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, RNN, LSTMCell, BatchNormalization, Conv2D, MaxPooling2D, Flatten, Reshape
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, classification_report

# %%
def load_data(dataset_path, img_size=(256, 256)):
    """
    Loads precomputed mel-spectrogram images and extracts labels from folder names.
    Resizes images to 256x256 for higher resolution.
    """
    X = []
    y = []
    class_names = sorted(os.listdir(dataset_path))  # Get emotion categories
    
    for label in class_names:
        class_path = os.path.join(dataset_path, label)
        if not os.path.isdir(class_path):
            continue
        
        files = glob.glob(os.path.join(class_path, '*.png'))
        print(f"Found {len(files)} images for class '{label}'.")
        
        for file in files:
            img = cv2.imread(file, cv2.IMREAD_GRAYSCALE)  # Load in grayscale
            img = cv2.resize(img, img_size)  # Resize to higher resolution
            X.append(img)
            y.append(label)
    
    X = np.array(X, dtype=np.float32) / 255.0  # Normalize pixel values
    y = np.array(y)
    return X, y, class_names

# %%
def augment_data(X, y, augmentation_factor=0.3):
    """Apply simple data augmentation to improve model generalization"""
    aug_X = []
    aug_y = []
    
    for i in range(len(X)):
        # Original sample
        aug_X.append(X[i])
        aug_y.append(y[i])
        
        # Apply time stretching (horizontal scaling)
        if np.random.random() < augmentation_factor:
            stretched = cv2.resize(X[i], (int(X[i].shape[1] * 1.1), X[i].shape[0]))
            stretched = cv2.resize(stretched, (X[i].shape[1], X[i].shape[0]))
            aug_X.append(stretched)
            aug_y.append(y[i])
        
        # Apply frequency masking (random horizontal lines masked)
        if np.random.random() < augmentation_factor:
            masked = X[i].copy()
            num_masks = np.random.randint(1, 5)  # More masks for larger image
            for _ in range(num_masks):
                freq_width = np.random.randint(8, 25)  # Wider masks for larger image
                freq_start = np.random.randint(0, X[i].shape[0] - freq_width)
                masked[freq_start:freq_start+freq_width, :] = 0
            aug_X.append(masked)
            aug_y.append(y[i])
        
        # Add pitch shift simulation (vertical shift)
        if np.random.random() < augmentation_factor:
            shift = X[i].copy()
            shift_amount = np.random.randint(-15, 16)
            if shift_amount > 0:
                shift = np.pad(shift, ((0, 0), (shift_amount, 0)), mode='constant')[:, :-shift_amount] if shift_amount > 0 else shift
            else:
                shift = np.pad(shift, ((0, 0), (0, -shift_amount)), mode='constant')[:, -shift_amount:] if shift_amount < 0 else shift
            aug_X.append(shift)
            aug_y.append(y[i])
    
    return np.array(aug_X), np.array(aug_y)

# %%
def preprocess_labels(y):
    """Encodes string labels into numerical one-hot vectors."""
    le = LabelEncoder()
    y_encoded = le.fit_transform(y)
    y_onehot = to_categorical(y_encoded)
    return y_onehot, le

# %%
def build_hybrid_model_256(input_shape, num_classes):
    """
    Builds a hybrid CNN-LSTM model for 256x256 inputs.
    Adjusted architecture to handle larger input dimensions.
    """
    model = Sequential()
    
    # CNN layers to extract spatial features
    model.add(Reshape((input_shape[0], input_shape[1], 1), input_shape=input_shape))
    
    # First conv block
    model.add(Conv2D(32, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(Conv2D(32, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))  # Output: 128x128x32
    
    # Second conv block
    model.add(Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))  # Output: 64x64x64
    
    # Third conv block
    model.add(Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))  # Output: 32x32x128
    
    # Fourth conv block - added for larger input size
    model.add(Conv2D(256, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))  # Output: 16x16x256
    
    # Reshape for LSTM - treat rows as time steps
    # After 4 MaxPooling layers, we have 16x16x256, reshape to 16 timesteps with 16*256 features
    model.add(Reshape((16, 16*256)))
    
    # LSTM layers for temporal features
    model.add(RNN(LSTMCell(384), return_sequences=True))  # Increased units for larger input
    model.add(Dropout(0.4))  # Slightly higher dropout for more regularization
    model.add(RNN(LSTMCell(192)))  # Increased units
    model.add(Dropout(0.4))
    
    # Classification layers
    model.add(Dense(192, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))
    model.add(Dense(96, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(num_classes, activation='softmax'))
    
    return model

# %%
def main():
    # Configuration parameters
    dataset_path = 'RAVDESS_mel_spectrograms'  # Update with your dataset path
    img_size = (256, 256)  # Increased from 192x192 to 256x256
    test_size = 0.15
    val_size = 0.15
    batch_size = 8  # Reduced batch size to account for larger model
    max_epochs = 500
    
    # Load and preprocess data with larger image size
    X, y, class_names = load_data(dataset_path, img_size)
    print(f"Original dataset: {X.shape[0]} samples")
    print(f"Image shape: {X[0].shape}")
    
    # Apply data augmentation
    X_aug, y_aug = augment_data(X, y)
    print(f"Augmented dataset: {X_aug.shape[0]} samples")
    
    # Encode labels
    y_onehot, le = preprocess_labels(y_aug)
    
    # Create train, validation, and test sets
    # First split off the test set
    X_temp, X_test, y_temp, y_test = train_test_split(
        X_aug, y_onehot, test_size=test_size, random_state=42, 
        stratify=np.argmax(y_onehot, axis=1)
    )
    
    # Then split the remaining data into train and validation
    val_ratio = val_size / (1 - test_size)
    X_train, X_val, y_train, y_val = train_test_split(
        X_temp, y_temp, test_size=val_ratio, random_state=42,
        stratify=np.argmax(y_temp, axis=1)
    )
    
    print(f"Train: {X_train.shape[0]}, Validation: {X_val.shape[0]}, Test: {X_test.shape[0]}")
    
    # Memory usage management
    tf.keras.backend.clear_session()
    
    # Build and compile the model for 256x256 inputs
    input_shape = X_train.shape[1:]  # (256, 256)
    num_classes = y_onehot.shape[1]
    model = build_hybrid_model_256(input_shape, num_classes)
    
    # Memory usage estimate
    param_count = model.count_params()
    print(f"Model has {param_count:,} parameters")
    
    # Create optimizer with learning rate
    initial_lr = 0.001
    optimizer = tf.keras.optimizers.Adam(learning_rate=initial_lr)
    
    model.compile(
        optimizer=optimizer,
        loss='categorical_crossentropy',
        metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
    )
    
    # Print model summary
    model.summary()
    
    # Callbacks for training
    checkpoint = ModelCheckpoint(
        'best_emotion_model_256x256.h5',
        monitor='val_loss',
        save_best_only=True,
        mode='min',
        verbose=1
    )
    
    early_stop = EarlyStopping(
        monitor='val_loss',
        patience=20,
        restore_best_weights=True,
        verbose=1
    )
    
    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=10,
        min_lr=1e-6,
        verbose=1
    )
    
    # Train the model
    try:
        history = model.fit(
            X_train, y_train,
            epochs=max_epochs,
            batch_size=batch_size,
            validation_data=(X_val, y_val),
            callbacks=[early_stop, checkpoint, reduce_lr],
            verbose=1
        )
        
        # Evaluate on the test set
        test_loss, test_acc, test_precision, test_recall = model.evaluate(X_test, y_test)
        print(f"Test Loss: {test_loss:.4f}")
        print(f"Test Accuracy: {test_acc:.4f}")
        print(f"Test Precision: {test_precision:.4f}")
        print(f"Test Recall: {test_recall:.4f}")
        
        # Generate predictions and evaluate in detail
        y_pred = model.predict(X_test)
        y_pred_classes = np.argmax(y_pred, axis=1)
        y_true_classes = np.argmax(y_test, axis=1)
        
        # Print classification report
        print("\nClassification Report:")
        print(classification_report(
            y_true_classes, 
            y_pred_classes, 
            target_names=[le.inverse_transform([i])[0] for i in range(num_classes)]
        ))
        
        # Plot training history
        plt.figure(figsize=(12, 4))
        
        plt.subplot(1, 2, 1)
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('Model Accuracy')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.legend(['Train', 'Validation'], loc='lower right')
        
        plt.subplot(1, 2, 2)
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.title('Model Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend(['Train', 'Validation'], loc='upper right')
        
        plt.tight_layout()
        plt.savefig('training_history_256x256.png')
        plt.show()
        
    except tf.errors.ResourceExhaustedError:
        print("Memory error encountered. Try reducing batch size or model complexity.")
        
    except Exception as e:
        print(f"Error during training: {e}")

# %%
if __name__ == '__main__':
    main()
# Out:
# Found 192 images for class 'angry'.
# Found 192 images for class 'calm'.
# Found 192 images for class 'disgust'.
# Found 192 images for class 'fearful'.
# Found 192 images for class 'happy'.
# Found 96 images for class 'neutral'.
# Found 192 images for class 'sad'.
# Found 192 images for class 'surprised'.
# Original dataset: 1440 samples
# Image shape: (256, 256)
# Augmented dataset: 2682 samples
# Train: 1876, Validation: 403, Test: 403
# Model has 7,967,880 parameters
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape (Reshape)           (None, 256, 256, 1)       0
#
#  conv2d (Conv2D)             (None, 256, 256, 32)      320
#
#  batch_normalization (BatchN  (None, 256, 256, 32)     128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 32)      9248
#
#  batch_normalization_1 (Batc  (None, 256, 256, 32)     128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 32)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 64)      18496
#
#  batch_normalization_2 (Batc  (None, 128, 128, 64)     256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 64)      36928
#
#  batch_normalization_3 (Batc  (None, 128, 128, 64)     256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 128)       73856
#
#  batch_normalization_4 (Batc  (None, 64, 64, 128)      512
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 128)       147584
#
#  batch_normalization_5 (Batc  (None, 64, 64, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 128)      0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 256)       295168
#
#  batch_normalization_6 (Batc  (None, 32, 32, 256)      1024
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 256)      0
#  2D)
#
#  reshape_1 (Reshape)         (None, 16, 4096)          0
#
#  rnn (RNN)                   (None, 16, 384)           6882816
#
#  dropout (Dropout)           (None, 16, 384)           0
#
#  rnn_1 (RNN)                 (None, 192)               443136
#
#  dropout_1 (Dropout)         (None, 192)               0
#
#  dense (Dense)               (None, 192)               37056
#
#  batch_normalization_7 (Batc  (None, 192)              768
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 192)               0
#
#  dense_1 (Dense)             (None, 96)                18528
#
#  batch_normalization_8 (Batc  (None, 96)               384
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 96)                0
#
#  dense_2 (Dense)             (None, 8)                 776
#
# =================================================================
# Total params: 7,967,880
# Trainable params: 7,965,896
# Non-trainable params: 1,984
# _________________________________________________________________
# Epoch 1/500
# 235/235 [==============================] - ETA: 0s - loss: 3.5910 - accuracy: 0.1354 - precision: 0.1438 - recall: 0.0442
# Epoch 1: val_loss improved from inf to 3.00588, saving model to best_emotion_model_256x256.h5
# 235/235 [==============================] - 17s 62ms/step - loss: 3.5910 - accuracy: 0.1354 - precision: 0.1438 - recall: 0.0442 - val_loss: 3.0059 - val_accuracy: 0.1340 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 0.0010
# Epoch 2/500
# 235/235 [==============================] - ETA: 0s - loss: 3.2887 - accuracy: 0.1397 - precision: 0.1565 - recall: 0.0219
# Epoch 2: val_loss improved from 3.00588 to 2.91854, saving model to best_emotion_model_256x256.h5
# 235/235 [==============================] - 14s 60ms/step - loss: 3.2887 - accuracy: 0.1397 - precision: 0.1565 - recall: 0.0219 - val_loss: 2.9185 - val_accuracy: 0.1390 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 0.0010
# Epoch 3/500
# 235/235 [==============================] - ETA: 0s - loss: 3.1258 - accuracy: 0.1327 - precision: 0.1136 - recall: 0.0080
# Epoch 3: val_loss improved from 2.91854 to 2.77882, saving model to best_emotion_model_256x256.h5
# 235/235 [==============================] -
500
# 235/235 [==============================] - ETA: 0s - loss: 1.6244 - accuracy: 0.4424 - precision: 0.6540 - recall: 0.2106
# Epoch 70: val_loss did not improve from 1.55220
# 235/235 [==============================] - 16s 67ms/step - loss: 1.6244 - accuracy: 0.4424 - precision: 0.6540 - recall: 0.2106 - val_loss: 1.7938 - val_accuracy: 0.3995 - val_precision: 0.5556 - val_recall: 0.2357 - lr: 2.5000e-04
# Epoch 71/500
# 235/235 [==============================] - ETA: 0s - loss: 1.5873 - accuracy: 0.4531 - precision: 0.6506 - recall: 0.2164
# Epoch 71: val_loss did not improve from 1.55220
# 235/235 [==============================] - 16s 69ms/step - loss: 1.5873 - accuracy: 0.4531 - precision: 0.6506 - recall: 0.2164 - val_loss: 1.7465 - val_accuracy: 0.3747 - val_precision: 0.5000 - val_recall: 0.2605 - lr: 2.5000e-04
# Epoch 72/500
# 235/235 [==============================] - ETA: 0s - loss: 1.6219 - accuracy: 0.4494 - precision: 0.6500 - recall: 0.2287
# Epoch 72: val_loss improved from 1.55220 to 1.45513, saving model to best_emotion_model_256x256.h5
# 235/235 [==============================] - 16s 70ms/step - loss: 1.6219 - accuracy: 0.4494 - precision: 0.6500 - recall: 0.2287 - val_loss: 1.4551 - val_accuracy: 0.5037 - val_precision: 0.6093 - val_recall: 0.3251 - lr: 2.5000e-04
# Epoch 73/500
# 235/235 [==============================] - ETA: 0s - loss: 1.6054 - accuracy: 0.4600 - precision: 0.6390 - recall: 0.2340
# Epoch 73: val_loss did not improve from 1.45513
# 235/235 [==============================] - 17s 70ms/step - loss: 1.6054 - accuracy: 0.4600 - precision: 0.6390 - recall: 0.2340 - val_loss: 2.1057 - val_accuracy: 0.3102 - val_precision: 0.4350 - val_recall: 0.2159 - lr: 2.5000e-04
# Epoch 74/500
# 235/235 [==============================] - ETA: 0s - loss: 1.5636 - accuracy: 0.4792 - precision: 0.6676 - recall: 0.2505
# Epoch 74: val_loss did not improve from 1.45513
# 235/235 [==============================] - 17s 71ms/step - loss: 1.5636 - accuracy: 0.4792 - precision: 0.6676 - recall: 0.2505 - val_loss: 1.9149 - val_accuracy: 0.3300 - val_precision: 0.5106 - val_recall: 0.1787 - lr: 2.5000e-04
# Epoch 75/500
# 235/235 [==============================] - ETA: 0s - loss: 1.5509 - accuracy: 0.4765 - precision: 0.6739 - recall: 0.2489
# Epoch 75: val_loss did not improve from 1.45513
# 235/235 [==============================] - 17s 72ms/step - loss: 1.5509 - accuracy: 0.4765 - precision: 0.6739 - recall: 0.2489 - val_loss: 1.7924 - val_accuracy: 0.3921 - val_precision: 0.4720 - val_recall: 0.2506 - lr: 2.5000e-04
# Epoch 76/500
# 235/235 [==============================] - ETA: 0s - loss: 1.5319 - accuracy: 0.4888 - precision: 0.6958 - recall: 0.2671
# Epoch 76: val_loss did not improve from 1.45513
# 235/235 [==============================] - 17s 71ms/step - loss: 1.5319 - accuracy: 0.4888 - precision: 0.6958 - recall: 0.2671 - val_loss: 1.8705 - val_accuracy: 0.3325 - val_precision: 0.5325 - val_recall: 0.2233 - lr: 2.5000e-04
# Epoch 77/500
# 235/235 [==============================] - ETA: 0s - loss: 1.5192 - accuracy: 0.4813 - precision: 0.6873 - recall: 0.2719
# Epoch 77: val_loss did not improve from 1.45513
# 235/235 [==============================] - 17s 73ms/step - loss: 1.5192 - accuracy: 0.4813 - precision: 0.6873 - recall: 0.2719 - val_loss: 2.0819 - val_accuracy: 0.3275 - val_precision: 0.4044 - val_recall: 0.2258 - lr: 2.5000e-04
# Epoch 78/500
# 235/235 [==============================] - ETA: 0s - loss: 1.5272 - accuracy: 0.4947 - precision: 0.6746 - recall: 0.2884
# Epoch 78: val_loss did not improve from 1.45513
# 235/235 [==============================] - 18s 75ms/step - loss: 1.5272 - accuracy: 0.4947 - precision: 0.6746 - recall: 0.2884 - val_loss: 1.9182 - val_accuracy: 0.3400 - val_precision: 0.4800 - val_recall: 0.2084 - lr: 2.5000e-04
# Epoch 79/500
# 235/235 [==============================] - ETA: 0s - loss: 1.5233 - accuracy: 0.4957 - precision: 0.6777 - recall: 0.2836
# Epoch 79: val_loss did not improve from 1.45513
# 235/235 [==============================] - 18s 75ms/step - loss: 1.5233 - accuracy: 0.4957 - precision: 0.6777 - recall: 0.2836 - val_loss: 2.7397 - val_accuracy: 0.2382 - val_precision: 0.2648 - val_recall: 0.1663 - lr: 2.5000e-04
# Epoch 80/500
# 235/235 [==============================] - ETA: 0s - loss: 1.4436 - accuracy: 0.5037 - precision: 0.7145 - recall: 0.3161
# Epoch 80: val_loss did not improve from 1.45513
# 235/235 [==============================] - 18s 75ms/step - loss: 1.4436 - accuracy: 0.5037 - precision: 0.7145 - recall: 0.3161 - val_loss: 2.3072 - val_accuracy: 0.2754 - val_precision: 0.3849 - val_recall: 0.2283 - lr: 2.5000e-04
# Epoch 81/500
# 235/235 [==============================] - ETA: 0s - loss: 1.4458 - accuracy: 0.5304 - precision: 0.6911 - recall: 0.3161
# Epoch 81: val_loss did not improve from 1.45513
# 235/235 [==============================] - 18s 75ms/step - loss: 1.4458 - accuracy: 0.5304 - precision: 0.6911 - recall: 0.3161 - val_loss: 1.6161 - val_accuracy: 0.4268 - val_precision: 0.5278 - val_recall: 0.2829 - lr: 2.5000e-04
# Epoch 82/500
# 235/235 [==============================] - ETA: 0s - loss: 1.4322 - accuracy: 0.5277 - precision: 0.6985 - recall: 0.3236
# Epoch 82: val_loss improved from 1.45513 to 1.34942, saving model to best_emotion_model_256x256.h5
# 235/235 [==============================] - 18s 75ms/step - loss: 1.4322 - accuracy: 0.5277 - precision: 0.6985 - recall: 0.3236 - val_loss: 1.3494 - val_accuracy: 0.5186 - val_precision: 0.6782 - val_recall: 0.3400 - lr: 2.5000e-04
# Epoch 83/500
# 235/235 [==============================] - ETA: 0s - loss: 1.4224 - accuracy: 0.5117 - precision: 0.7071 - recall: 0.3358
# Epoch 83: val_loss did not improve from 1.34942
# 235/235 [==============================] - 18s 75ms/step - loss: 1.4224 - accuracy: 0.5117 - precision: 0.7071 - recall: 0.3358 - val_loss: 1.5235 - val_accuracy: 0.4839 - val_precision: 0.6635 - val_recall: 0.3474 - lr: 2.5000e-04
# Epoch 84/500
# 235/235 [==============================] - ETA: 0s - loss: 1.4074 - accuracy: 0.5309 - precision: 0.7227 - recall: 0.3486
# Epoch 84: val_loss did not improve from 1.34942
# 235/235 [==============================] - 18s 74ms/step - loss: 1.4074 - accuracy: 0.5309 - precision: 0.7227 - recall: 0.3486 - val_loss: 1.5028 - val_accuracy: 0.4888 - val_precision: 0.6041 - val_recall: 0.3672 - lr: 2.5000e-04
# Epoch 85/500
# 235/235 [==============================] - ETA: 0s - loss: 1.4329 - accuracy: 0.5314 - precision: 0.6921 - recall: 0.3332
# Epoch 85: val_loss did not improve from 1.34942
# 235/235 [==============================] - 17s 73ms/step - loss: 1.4329 - accuracy: 0.5314 - precision: 0.6921 - recall: 0.3332 - val_loss: 1.3943 - val_accuracy: 0.5112 - val_precision: 0.6463 - val_recall: 0.3672 - lr: 2.5000e-04
# Epoch 86/500
# 235/235 [==============================] - ETA: 0s - loss: 1.3460 - accuracy: 0.5634 - precision: 0.7434 - recall: 0.3753
# Epoch 86: val_loss did not improve from 1.34942
# 235/235 [==============================] - 17s 71ms/step - loss: 1.3460 - accuracy: 0.5634 - precision: 0.7434 - recall: 0.3753 - val_loss: 2.5287 - val_accuracy: 0.2630 - val_precision: 0.3208 - val_recall: 0.2109 - lr: 2.5000e-04
# Epoch 87/500
# 235/235 [==============================] - ETA: 0s - loss: 1.4381 - accuracy: 0.5325 - precision: 0.7087 - recall: 0.3502
# Epoch 87: val_loss did not improve from 1.34942
# 235/235 [==============================] - 17s 73ms/step - loss: 1.4381 - accuracy: 0.5325 - precision: 0.7087 - recall: 0.3502 - val_loss: 2.4361 - val_accuracy: 0.2829 - val_precision: 0.3220 - val_recall: 0.2357 - lr: 2.5000e-04
# Epoch 88/500
# 235/235 [==============================] - ETA: 0s - loss: 1.3818 - accuracy: 0.5448 - precision: 0.7062 - recall: 0.3614
# Epoch 88: val_loss improved from 1.34942 to 1.28030, saving model to best_emotion_model_256x256.h5
# 235/235 [==============================] - 17s 73ms/step - loss: 1.3818 - accuracy: 0.5448 - precision: 0.7062 - recall: 0.3614 - val_loss: 1.2803 - val_accuracy: 0.5757 - val_precision: 0.6716 - val_recall: 0.4516 - lr: 2.5000e-04
# Epoch 89/500
# 235/235 [==============================] - ETA: 0s - loss: 1.3640 - accuracy: 0.5602 - precision: 0.7207 - recall: 0.3907
# Epoch 89: val_loss did not improve from 1.28030
# 235/235 [==============================] - 17s 72ms/step - loss: 1.3640 - accuracy: 0.5602 - precision: 0.7207 - recall: 0.3907 - val_loss: 2.5410 - val_accuracy: 0.2283 - val_precision: 0.3012 - val_recall: 0.1861 - lr: 2.5000e-04
# Epoch 90/500
# 235/235 [==============================] - ETA: 0s - loss: 1.3212 - accuracy: 0.5736 - precision: 0.7233 - recall: 0.3902
# Epoch 90: val_loss did not improve from 1.28030
# 235/235 [==============================] - 17s 71ms/step - loss: 1.3212 - accuracy: 0.5736 - precision: 0.7233 - recall: 0.3902 - val_loss: 1.7012 - val_accuracy: 0.4144 - val_precision: 0.4961 - val_recall: 0.3176 - lr: 2.5000e-04
# Epoch 91/500
# 235/235 [==============================] - ETA: 0s - loss: 1.3210 - accuracy: 0.5805 - precision: 0.7242 - recall: 0.4227
# Epoch 91: val_loss did not improve from 1.28030
# 235/235 [==============================] - 17s 71ms/step - loss: 1.3210 - accuracy: 0.5805 - precision: 0.7242 - recall: 0.4227 - val_loss: 1.4409 - val_accuracy: 0.5136 - val_precision: 0.6281 - val_recall: 0.3772 - lr: 2.5000e-04
# Epoch 92/500
# 235/235 [==============================] - ETA: 0s - loss: 1.3539 - accuracy: 0.5677 - precision: 0.7195 - recall: 0.4088
# Epoch 92: val_loss improved from 1.28030 to 1.16191, saving model to best_emotion_model_256x256.h5
# 235/235 [==============================] - 17s
saving model to best_emotion_model_256x256.h5
# 235/235 [==============================] - 17s 71ms/step - loss: 0.7103 - accuracy: 0.8220 - precision: 0.8718 - recall: 0.7687 - val_loss: 0.8943 - val_accuracy: 0.7469 - val_precision: 0.7804 - val_recall: 0.7320 - lr: 1.2500e-04
# Epoch 126/500
# 235/235 [==============================] - ETA: 0s - loss: 0.6750 - accuracy: 0.8230 - precision: 0.8814 - recall: 0.7841
# Epoch 126: val_loss improved from 0.89427 to 0.85520, saving model to best_emotion_model_256x256.h5
# 235/235 [==============================] - 17s 71ms/step - loss: 0.6750 - accuracy: 0.8230 - precision: 0.8814 - recall: 0.7841 - val_loss: 0.8552 - val_accuracy: 0.7767 - val_precision: 0.8031 - val_recall: 0.7593 - lr: 1.2500e-04
# Epoch 127/500
# 235/235 [==============================] - ETA: 0s - loss: 0.6318 - accuracy: 0.8428 - precision: 0.8877 - recall: 0.8049
# Epoch 127: val_loss improved from 0.85520 to 0.84424, saving model to best_emotion_model_256x256.h5
# 235/235 [==============================] - 17s 72ms/step - loss: 0.6318 - accuracy: 0.8428 - precision: 0.8877 - recall: 0.8049 - val_loss: 0.8442 - val_accuracy: 0.7866 - val_precision: 0.8016 - val_recall: 0.7519 - lr: 1.2500e-04
# Epoch 128/500
# 235/235 [==============================] - ETA: 0s - loss: 0.6607 - accuracy: 0.8385 - precision: 0.8718 - recall: 0.7937
# Epoch 128: val_loss did not improve from 0.84424
# 235/235 [==============================] - 16s 69ms/step - loss: 0.6607 - accuracy: 0.8385 - precision: 0.8718 - recall: 0.7937 - val_loss: 1.0898 - val_accuracy: 0.6973 - val_precision: 0.7357 - val_recall: 0.6700 - lr: 1.2500e-04
# Epoch 129/500
# 235/235 [==============================] - ETA: 0s - loss: 0.6844 - accuracy: 0.8358 - precision: 0.8759 - recall: 0.8054
# Epoch 129: val_loss did not improve from 0.84424
# 235/235 [==============================] - 16s 69ms/step - loss: 0.6844 - accuracy: 0.8358 - precision: 0.8759 - recall: 0.8054 - val_loss: 1.8750 - val_accuracy: 0.5409 - val_precision: 0.5603 - val_recall: 0.5186 - lr: 1.2500e-04
# Epoch 130/500
# 235/235 [==============================] - ETA: 0s - loss: 0.6201 - accuracy: 0.8598 - precision: 0.8980 - recall: 0.8214
# Epoch 130: val_loss did not improve from 0.84424
# 235/235 [==============================] - 16s 69ms/step - loss: 0.6201 - accuracy: 0.8598 - precision: 0.8980 - recall: 0.8214 - val_loss: 4.7412 - val_accuracy: 0.2605 - val_precision: 0.2594 - val_recall: 0.2556 - lr: 1.2500e-04
# Epoch 131/500
# 235/235 [==============================] - ETA: 0s - loss: 0.5979 - accuracy: 0.8507 - precision: 0.8931 - recall: 0.8193
# Epoch 131: val_loss did not improve from 0.84424
# 235/235 [==============================] - 16s 69ms/step - loss: 0.5979 - accuracy: 0.8507 - precision: 0.8931 - recall: 0.8193 - val_loss: 0.9012 - val_accuracy: 0.7618 - val_precision: 0.7906 - val_recall: 0.7494 - lr: 1.2500e-04
# Epoch 132/500
# 235/235 [==============================] - ETA: 0s - loss: 0.5891 - accuracy: 0.8609 - precision: 0.8972 - recall: 0.8236
# Epoch 132: val_loss did not improve from 0.84424
# 235/235 [==============================] - 16s 70ms/step - loss: 0.5891 - accuracy: 0.8609 - precision: 0.8972 - recall: 0.8236 - val_loss: 0.9605 - val_accuracy: 0.7494 - val_precision: 0.7676 - val_recall: 0.7295 - lr: 1.2500e-04
# Epoch 133/500
# 235/235 [==============================] - ETA: 0s - loss: 0.5604 - accuracy: 0.8737 - precision: 0.9028 - recall: 0.8321
# Epoch 133: val_loss did not improve from 0.84424
# 235/235 [==============================] - 16s 68ms/step - loss: 0.5604 - accuracy: 0.8737 - precision: 0.9028 - recall: 0.8321 - val_loss: 1.6964 - val_accuracy: 0.5707 - val_precision: 0.6050 - val_recall: 0.5360 - lr: 1.2500e-04
# Epoch 134/500
# 235/235 [==============================] - ETA: 0s - loss: 0.5560 - accuracy: 0.8683 - precision: 0.9005 - recall: 0.8438
# Epoch 134: val_loss did not improve from 0.84424
# 235/235 [==============================] - 16s 68ms/step - loss: 0.5560 - accuracy: 0.8683 - precision: 0.9005 - recall: 0.8438 - val_loss: 1.0994 - val_accuracy: 0.7270 - val_precision: 0.7493 - val_recall: 0.7122 - lr: 1.2500e-04
# Epoch 135/500
# 235/235 [==============================] - ETA: 0s - loss: 0.5599 - accuracy: 0.8662 - precision: 0.8944 - recall: 0.8396
# Epoch 135: val_loss did not improve from 0.84424
# 235/235 [==============================] - 16s 68ms/step - loss: 0.5599 - accuracy: 0.8662 - precision: 0.8944 - recall: 0.8396 - val_loss: 2.0270 - val_accuracy: 0.5360 - val_precision: 0.5445 - val_recall: 0.5161 - lr: 1.2500e-04
# Epoch 136/500
# 235/235 [==============================] - ETA: 0s - loss: 0.5592 - accuracy: 0.8657 - precision: 0.8924 - recall: 0.8401
# Epoch 136: val_loss did not improve from 0.84424
# 235/235 [==============================] - 16s 70ms/step - loss: 0.5592 - accuracy: 0.8657 - precision: 0.8924 - recall: 0.8401 - val_loss: 0.9761 - val_accuracy: 0.7519 - val_precision: 0.7704 - val_recall: 0.7494 - lr: 1.2500e-04
# Epoch 137/500
# 235/235 [==============================] - ETA: 0s - loss: 0.5589 - accuracy: 0.8710 - precision: 0.8997 - recall: 0.8465
# Epoch 137: val_loss did not improve from 0.84424
#
# Epoch 137: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 235/235 [==============================] - 16s 68ms/step - loss: 0.5589 - accuracy: 0.8710 - precision: 0.8997 - recall: 0.8465 - val_loss: 1.3336 - val_accuracy: 0.6328 - val_precision: 0.6648 - val_recall: 0.6005 - lr: 1.2500e-04
# Epoch 138/500
# 235/235 [==============================] - ETA: 0s - loss: 0.4957 - accuracy: 0.8886 - precision: 0.9113 - recall: 0.8651
# Epoch 138: val_loss improved from 0.84424 to 0.79257, saving model to best_emotion_model_256x256.h5
# 235/235 [==============================] - 16s 69ms/step - loss: 0.4957 - accuracy: 0.8886 - precision: 0.9113 - recall: 0.8651 - val_loss: 0.7926 - val_accuracy: 0.7940 - val_precision: 0.8144 - val_recall: 0.7841 - lr: 6.2500e-05
# Epoch 139/500
# 235/235 [==============================] - ETA: 0s - loss: 0.4949 - accuracy: 0.8945 - precision: 0.9170 - recall: 0.8715
# Epoch 139: val_loss did not improve from 0.79257
# 235/235 [==============================] - 16s 68ms/step - loss: 0.4949 - accuracy: 0.8945 - precision: 0.9170 - recall: 0.8715 - val_loss: 0.8325 - val_accuracy: 0.7940 - val_precision: 0.8088 - val_recall: 0.7767 - lr: 6.2500e-05
# Epoch 140/500
# 235/235 [==============================] - ETA: 0s - loss: 0.4377 - accuracy: 0.9035 - precision: 0.9289 - recall: 0.8849
# Epoch 140: val_loss did not improve from 0.79257
# 235/235 [==============================] - 16s 67ms/step - loss: 0.4377 - accuracy: 0.9035 - precision: 0.9289 - recall: 0.8849 - val_loss: 0.8714 - val_accuracy: 0.7717 - val_precision: 0.7932 - val_recall: 0.7519 - lr: 6.2500e-05
# Epoch 141/500
# 235/235 [==============================] - ETA: 0s - loss: 0.4605 - accuracy: 0.9051 - precision: 0.9199 - recall: 0.8811
# Epoch 141: val_loss did not improve from 0.79257
# 235/235 [==============================] - 16s 69ms/step - loss: 0.4605 - accuracy: 0.9051 - precision: 0.9199 - recall: 0.8811 - val_loss: 0.8589 - val_accuracy: 0.7841 - val_precision: 0.7979 - val_recall: 0.7643 - lr: 6.2500e-05
# Epoch 142/500
# 235/235 [==============================] - ETA: 0s - loss: 0.4459 - accuracy: 0.9126 - precision: 0.9362 - recall: 0.8918
# Epoch 142: val_loss did not improve from 0.79257
# 235/235 [==============================] - 16s 67ms/step - loss: 0.4459 - accuracy: 0.9126 - precision: 0.9362 - recall: 0.8918 - val_loss: 0.8714 - val_accuracy: 0.7866 - val_precision: 0.8062 - val_recall: 0.7742 - lr: 6.2500e-05
# Epoch 143/500
# 235/235 [==============================] - ETA: 0s - loss: 0.4333 - accuracy: 0.9104 - precision: 0.9330 - recall: 0.8907
# Epoch 143: val_loss did not improve from 0.79257
# 235/235 [==============================] - 16s 68ms/step - loss: 0.4333 - accuracy: 0.9104 - precision: 0.9330 - recall: 0.8907 - val_loss: 0.8547 - val_accuracy: 0.7916 - val_precision: 0.7980 - val_recall: 0.7742 - lr: 6.2500e-05
# Epoch 144/500
# 235/235 [==============================] - ETA: 0s - loss: 0.4198 - accuracy: 0.9120 - precision: 0.9307 - recall: 0.8955
# Epoch 144: val_loss did not improve from 0.79257
# 235/235 [==============================] - 17s 72ms/step - loss: 0.4198 - accuracy: 0.9120 - precision: 0.9307 - recall: 0.8955 - val_loss: 0.8061 - val_accuracy: 0.7990 - val_precision: 0.8243 - val_recall: 0.7916 - lr: 6.2500e-05
# Epoch 145/500
# 235/235 [==============================] - ETA: 0s - loss: 0.4334 - accuracy: 0.9062 - precision: 0.9225 - recall: 0.8881
# Epoch 145: val_loss did not improve from 0.79257
# 235/235 [==============================] - 16s 68ms/step - loss: 0.4334 - accuracy: 0.9062 - precision: 0.9225 - recall: 0.8881 - val_loss: 1.1536 - val_accuracy: 0.6923 - val_precision: 0.7256 - val_recall: 0.6824 - lr: 6.2500e-05
# Epoch 146/500
# 235/235 [==============================] - ETA: 0s - loss: 0.4000 - accuracy: 0.9147 - precision: 0.9353 - recall: 0.9019
# Epoch 146: val_loss did not improve from 0.79257
# 235/235 [==============================] - 16s 70ms/step - loss: 0.4000 - accuracy: 0.9147 - precision: 0.9353 - recall: 0.9019 - val_loss: 0.8149 - val_accuracy: 0.7940 - val_precision: 0.8170 - val_recall: 0.7866 - lr: 6.2500e-05
# Epoch 147/500
# 235/235 [==============================] - ETA: 0s - loss: 0.4113 - accuracy: 0.9147 - precision: 0.9300 - recall: 0.8993
# Epoch 147: val_loss did not improve from 0.79257
# 235/235 [==============================] - 16s 69ms/step - loss: 0.4113 - accuracy: 0.9147 - precision: 0.9300 - recall: 0.8993 - val_loss: 0.8782 - val_accuracy: 0.8015 - val_precision: 0.8071 - val_recall: 0.7891 - lr: 6.2500e-05
# Epoch 148/500
# 235/235 [==============================] - ETA: 0s - loss: 0.4090 - accuracy: 0.9264 - precision: 0.9446 - recall: 0.9083
# Epoch 148: val_loss did not improve from 0.79257
#
# Epoch 148: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 235/235 [==============================] - 18s 76ms/step - loss: 0.4090 - accuracy: 0.9264 - precision: 0.9446 - recall: 0.9083 - val_loss: 0.8967 - val_accuracy: 0.7816 - val_precision: 0.7995 - val_recall: 0.7717 - lr: 6.2500e-05
# Epoch 149/500
# 235/235 [==============================] - ETA: 0s - loss: 0.3641 - accuracy: 0.9270 - precision: 0.9453 - recall: 0.9126
# Epoch 149: val_loss did not improve from 0.79257
# 235/235 [==============================] - 17s 74ms/step - loss: 0.3641 - accuracy: 0.9270 - precision: 0.9453 - recall: 0.9126 - val_loss: 0.8890 - val_accuracy: 0.8015 - val_precision: 0.8035 - val_recall: 0.7916 - lr: 3.1250e-05
# Epoch 150/500
# 235/235 [==============================] - ETA: 0s - loss: 0.3312 - accuracy: 0.9403 - precision: 0.9536 - recall: 0.9312
# Epoch 150: val_loss did not improve from 0.79257
# 235/235 [==============================] - 17s 72ms/step - loss: 0.3312 - accuracy: 0.9403 - precision: 0.9536 - recall: 0.9312 - val_loss: 0.8679 - val_accuracy: 0.8114 - val_precision: 0.8231 - val_recall: 0.7965 - lr: 3.1250e-05
# Epoch 151/500
# 235/235 [==============================] - ETA: 0s - loss: 0.3354 - accuracy: 0.9355 - precision: 0.9527 - recall: 0.9232
# Epoch 151: val_loss did not improve from 0.79257
# 235/235 [==============================] - 17s 72ms/step - loss: 0.3354 - accuracy: 0.9355 - precision: 0.9527 - recall: 0.9232 - val_loss: 0.8715 - val_accuracy: 0.7717 - val_precision: 0.7949 - val_recall: 0.7692 - lr: 3.1250e-05
# Epoch 152/500
# 235/235 [==============================] - ETA: 0s - loss: 0.3519 - accuracy: 0.9382 - precision: 0.9530 - recall: 0.9190
# Epoch 152: val_loss did not improve from 0.79257
# 235/235 [==============================] - 17s 71ms/step - loss: 0.3519 - accuracy: 0.9382 - precision: 0.9530 - recall: 0.9190 - val_loss: 1.0385 - val_accuracy: 0.7519 - val_precision: 0.7615 - val_recall: 0.7370 - lr: 3.1250e-05
# Epoch 153/500
# 235/235 [==============================] - ETA: 0s - loss: 0.3218 - accuracy: 0.9478 - precision: 0.9575 - recall: 0.9371
# Epoch 153: val_loss did not improve from 0.79257
# 235/235 [==============================] - 17s 72ms/step - loss: 0.3218 - accuracy: 0.9478 - precision: 0.9575 - recall: 0.9371 - val_loss: 0.8605 - val_accuracy: 0.8114 - val_precision: 0.8177 - val_recall: 0.8015 - lr: 3.1250e-05
# Epoch 154/500
# 235/235 [==============================] - ETA: 0s - loss: 0.3411 - accuracy: 0.9302 - precision: 0.9429 - recall: 0.9147
# Epoch 154: val_loss did not improve from 0.79257
# 235/235 [==============================] - 17s 72ms/step - loss: 0.3411 - accuracy: 0.9302 - precision: 0.9429 - recall: 0.9147 - val_loss: 0.8750 - val_accuracy: 0.7866 - val_precision: 0.7909 - val_recall: 0.7792 - lr: 3.1250e-05
# Epoch 155/500
# 235/235 [==============================] - ETA: 0s - loss: 0.3330 - accuracy: 0.9419 - precision: 0.9515 - recall: 0.9307
# Epoch 155: val_loss did not improve from 0.79257
# 235/235 [==============================] - 17s 71ms/step - loss: 0.3330 - accuracy: 0.9419 - precision: 0.9515 - recall: 0.9307 - val_loss: 0.8322 - val_accuracy: 0.8089 - val_precision: 0.8177 - val_recall: 0.8015 - lr: 3.1250e-05
# Epoch 156/500
# 235/235 [==============================] - ETA: 0s - loss: 0.3184 - accuracy: 0.9451 - precision: 0.9558 - recall: 0.9334
# Epoch 156: val_loss did not improve from 0.79257
# 235/235 [==============================] - 17s 72ms/step - loss: 0.3184 - accuracy: 0.9451 - precision: 0.9558 - recall: 0.9334 - val_loss: 0.9422 - val_accuracy: 0.7866 - val_precision: 0.7980 - val_recall: 0.7742 - lr: 3.1250e-05
# Epoch 157/500
# 235/235 [==============================] - ETA: 0s - loss: 0.3118 - accuracy: 0.9456 - precision: 0.9574 - recall: 0.9339
# Epoch 157: val_loss did not improve from 0.79257
# 235/235 [==============================] - 18s 76ms/step - loss: 0.3118 - accuracy: 0.9456 - precision: 0.9574 - recall: 0.9339 - val_loss: 0.8160 - val_accuracy: 0.8189 - val_precision: 0.8262 - val_recall: 0.8139 - lr: 3.1250e-05
# Epoch 158/500
# 235/235 [==============================] - ETA: 0s - loss: 0.3137 - accuracy: 0.9414 - precision: 0.9583 - recall: 0.9312Restoring model weights from the end of the best epoch: 138.
#
# Epoch 158: val_loss did not improve from 0.79257
#
# Epoch 158: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 235/235 [==============================] - 17s 72ms/step - loss: 0.3137 - accuracy: 0.9414 - precision: 0.9583 - recall: 0.9312 - val_loss: 0.8889 - val_accuracy: 0.8065 - val_precision: 0.8173 - val_recall: 0.7990 - lr: 3.1250e-05
# Epoch 158: early stopping
# 13/13 [==============================] - 0s 18ms/step - loss: 1.1027 - accuracy: 0.7568 - precision: 0.7789 - recall: 0.7345
# Test Loss: 1.1027
# Test Accuracy: 0.7568
# Test Precision: 0.7789
# Test Recall: 0.7345
# 13/13 [==============================] - 1s 16ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.84      0.77      0.80        56
#         calm       0.79      0.89      0.84        55
#      disgust       0.86      0.86      0.86        56
#      fearful       0.71      0.75      0.73        53
#        happy       0.69      0.57      0.62        51
#      neutral       0.56      0.62      0.59        24
#          sad       0.66      0.74      0.70        53
#    surprised       0.84      0.76      0.80        55
#
#     accuracy                           0.76       403
#    macro avg       0.74      0.75      0.74       403
# weighted avg       0.76      0.76      0.76       403
