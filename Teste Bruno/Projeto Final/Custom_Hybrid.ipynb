# %%
import os
import glob
import numpy as np
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, RNN, LSTMCell, BatchNormalization, Conv2D, MaxPooling2D, Flatten, Reshape
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, classification_report

def load_data(dataset_path, img_size=(128, 128)):
    """
    Loads precomputed mel-spectrogram images and extracts labels from folder names.
    Returns both raw data and data split into training, validation, and test sets.
    """
    X = []
    y = []
    class_names = sorted(os.listdir(dataset_path))  # Get emotion categories
    
    for label in class_names:
        class_path = os.path.join(dataset_path, label)
        if not os.path.isdir(class_path):
            continue
        
        files = glob.glob(os.path.join(class_path, '*.png'))
        print(f"Found {len(files)} images for class '{label}'.")
        
        for file in files:
            img = cv2.imread(file, cv2.IMREAD_GRAYSCALE)  # Load in grayscale
            img = cv2.resize(img, img_size)  # Resize to standard size
            X.append(img)
            y.append(label)
    
    X = np.array(X, dtype=np.float32) / 255.0  # Normalize pixel values
    y = np.array(y)
    return X, y, class_names

def augment_data(X, y, augmentation_factor=0.3):
    """Apply simple data augmentation to improve model generalization"""
    aug_X = []
    aug_y = []
    
    for i in range(len(X)):
        # Original sample
        aug_X.append(X[i])
        aug_y.append(y[i])
        
        # Apply time stretching (horizontal scaling)
        if np.random.random() < augmentation_factor:
            stretched = cv2.resize(X[i], (int(X[i].shape[1] * 1.1), X[i].shape[0]))
            stretched = cv2.resize(stretched, (X[i].shape[1], X[i].shape[0]))
            aug_X.append(stretched)
            aug_y.append(y[i])
        
        # Apply frequency masking (random horizontal lines masked)
        if np.random.random() < augmentation_factor:
            masked = X[i].copy()
            num_masks = np.random.randint(1, 4)
            for _ in range(num_masks):
                freq_width = np.random.randint(5, 15)
                freq_start = np.random.randint(0, X[i].shape[0] - freq_width)
                masked[freq_start:freq_start+freq_width, :] = 0
            aug_X.append(masked)
            aug_y.append(y[i])
    
    return np.array(aug_X), np.array(aug_y)

def preprocess_labels(y):
    """Encodes string labels into numerical one-hot vectors."""
    le = LabelEncoder()
    y_encoded = le.fit_transform(y)
    y_onehot = to_categorical(y_encoded)
    return y_onehot, le

def build_hybrid_model(input_shape, num_classes):
    """
    Builds a hybrid CNN-LSTM model that leverages both spatial and temporal features.
    """
    model = Sequential()
    
    # First, add CNN layers to extract spatial features
    model.add(Reshape((input_shape[0], input_shape[1], 1), input_shape=input_shape))
    model.add(Conv2D(32, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    
    model.add(Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    
    # Reshape for LSTM - treat rows as time steps
    model.add(Reshape((32, 32*64)))
    
    # LSTM layers for temporal features
    model.add(RNN(LSTMCell(128), return_sequences=True))
    model.add(Dropout(0.3))
    model.add(RNN(LSTMCell(64)))
    model.add(Dropout(0.3))
    
    # Classification layers
    model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(num_classes, activation='softmax'))
    
    return model

def main():
    # Configuration parameters
    dataset_path = 'RAVDESS_mel_spectrograms'  # Update with your dataset path
    img_size = (128, 128)
    test_size = 0.15
    val_size = 0.15
    batch_size = 16
    max_epochs = 100
    
    # Load and preprocess data
    X, y, class_names = load_data(dataset_path, img_size)
    print(f"Original dataset: {X.shape[0]} samples")
    
    # Apply data augmentation
    X_aug, y_aug = augment_data(X, y)
    print(f"Augmented dataset: {X_aug.shape[0]} samples")
    
    # Encode labels
    y_onehot, le = preprocess_labels(y_aug)
    
    # Create train, validation, and test sets
    # First split off the test set
    X_temp, X_test, y_temp, y_test = train_test_split(
        X_aug, y_onehot, test_size=test_size, random_state=42, 
        stratify=np.argmax(y_onehot, axis=1)
    )
    
    # Then split the remaining data into train and validation
    val_ratio = val_size / (1 - test_size)
    X_train, X_val, y_train, y_val = train_test_split(
        X_temp, y_temp, test_size=val_ratio, random_state=42,
        stratify=np.argmax(y_temp, axis=1)
    )
    
    print(f"Train: {X_train.shape[0]}, Validation: {X_val.shape[0]}, Test: {X_test.shape[0]}")
    
    # Build and compile the model
    input_shape = X_train.shape[1:]  # (128, 128)
    num_classes = y_onehot.shape[1]
    model = build_hybrid_model(input_shape, num_classes)
    
    # Use a learning rate schedule with warmup
    initial_lr = 0.001
    optimizer = tf.keras.optimizers.Adam(learning_rate=initial_lr)
    
    model.compile(
        optimizer=optimizer,
        loss='categorical_crossentropy',
        metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
    )
    
    # Print model summary
    model.summary()
    
    # Callbacks for training
    checkpoint = ModelCheckpoint(
        'best_emotion_model.h5',
        monitor='val_loss',
        save_best_only=True,
        mode='min',
        verbose=1
    )
    
    early_stop = EarlyStopping(
        monitor='val_loss',
        patience=20,
        restore_best_weights=True,
        verbose=1
    )
    
    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=10,
        min_lr=1e-6,
        verbose=1
    )
    
    # Train the model
    history = model.fit(
        X_train, y_train,
        epochs=max_epochs,
        batch_size=batch_size,
        validation_data=(X_val, y_val),
        callbacks=[early_stop, checkpoint, reduce_lr],
        verbose=1
    )
    
    # Evaluate on the test set
    test_loss, test_acc, test_precision, test_recall = model.evaluate(X_test, y_test)
    print(f"Test Loss: {test_loss:.4f}")
    print(f"Test Accuracy: {test_acc:.4f}")
    print(f"Test Precision: {test_precision:.4f}")
    print(f"Test Recall: {test_recall:.4f}")
    
    # Generate predictions and evaluate in detail
    y_pred = model.predict(X_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true_classes = np.argmax(y_test, axis=1)
    
    # Print classification report
    print("\nClassification Report:")
    print(classification_report(
        y_true_classes, 
        y_pred_classes, 
        target_names=[le.inverse_transform([i])[0] for i in range(num_classes)]
    ))
    
    # Plot training history
    plt.figure(figsize=(12, 4))
    
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'], loc='lower right')
    
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(['Train', 'Validation'], loc='upper right')
    
    plt.tight_layout()
    plt.savefig('training_history.png')
    plt.show()

if __name__ == '__main__':
    main()
# Out:
# Found 192 images for class 'angry'.
# Found 192 images for class 'calm'.
# Found 192 images for class 'disgust'.
# Found 192 images for class 'fearful'.
# Found 192 images for class 'happy'.
# Found 96 images for class 'neutral'.
# Found 192 images for class 'sad'.
# Found 192 images for class 'surprised'.
# Original dataset: 1440 samples
# Augmented dataset: 2288 samples
# Train: 1600, Validation: 344, Test: 344
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape (Reshape)           (None, 128, 128, 1)       0
#
#  conv2d (Conv2D)             (None, 128, 128, 32)      320
#
#  batch_normalization (BatchN  (None, 128, 128, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)        18496
#
#  batch_normalization_1 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  reshape_1 (Reshape)         (None, 32, 2048)          0
#
#  rnn (RNN)                   (None, 32, 128)           1114624
#
#  dropout (Dropout)           (None, 32, 128)           0
#
#  rnn_1 (RNN)                 (None, 64)                49408
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 64)                4160
#
#  batch_normalization_2 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 8)                 520
#
# =================================================================
# Total params: 1,188,168
# Trainable params: 1,187,848
# Non-trainable params: 320
# _________________________________________________________________
# Epoch 1/100
# 100/100 [==============================] - ETA: 0s - loss: 2.6092 - accuracy: 0.1356 - precision: 0.1713 - recall: 0.0350
# Epoch 1: val_loss improved from inf to 2.20204, saving model to best_emotion_model.h5
# 100/100 [==============================] - 8s 67ms/step - loss: 2.6092 - accuracy: 0.1356 - precision: 0.1713 - recall: 0.0350 - val_loss: 2.2020 - val_accuracy: 0.1424 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 0.0010
# Epoch 2/100
# 100/100 [==============================] - ETA: 0s - loss: 2.2808 - accuracy: 0.2031 - precision: 0.2944 - recall: 0.0331
# Epoch 2: val_loss did not improve from 2.20204
# 100/100 [==============================] - 6s 63ms/step - loss: 2.2808 - accuracy: 0.2031 - precision: 0.2944 - recall: 0.0331 - val_loss: 2.2296 - val_accuracy: 0.1366 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 0.0010
# Epoch 3/100
# 100/100 [==============================] - ETA: 0s - loss: 2.1524 - accuracy: 0.2387 - precision: 0.3476 - recall: 0.0356
# Epoch 3: val_loss did not improve from 2.20204
# 100/100 [==============================] - 6s 63ms/step - loss: 2.1524 - accuracy: 0.2387 - precision: 0.3476 - recall: 0.0356 - val_loss: 2.2810 - val_accuracy: 0.1628 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 0.0010
# Epoch 4/100
# 100/100 [==============================] - ETA: 0s - loss: 2.0802 - accuracy: 0.2406 - precision: 0.3889 - recall: 0.0394
# Epoch 4: val_loss improved from 2.20204 to 2.04530, saving model to best_emotion_model.h5
# 100/100 [==============================] - 6s 64ms/step - loss: 2.0802 - accuracy: 0.2406 - precision: 0.3889 - recall: 0.0394 - val_loss: 2.0453 - val_accuracy: 0.2006 - val_precision: 1.0000 - val_recall: 0.0029 - lr: 0.0010
# Epoch 5/100
# 100/100 [==============================] - ETA: 0s - loss: 1.9214 - accuracy: 0.2862 - precision: 0.4917 - recall: 0.0556
# Epoch 5: val_loss did not improve from 2.04530
# 100/100 [==============================] - 6s 64ms/step - loss: 1.9214 - accuracy: 0.2862 - precision: 0.4917 - recall: 0.0556 - val_loss: 2.3317 - val_accuracy: 0.2180 - val_precision: 0.6667 - val_recall: 0.0174 - lr: 0.0010
# Epoch 6/100
# 100/100 [==============================] - ETA: 0s - loss: 1.9433 - accuracy: 0.2800 - precision: 0.4591 - recall: 0.0631
# Epoch 6: val_loss improved from 2.04530 to 2.02270, saving model to best_emotion_model.h5
# 100/100 [==============================] - 6s 64ms/step - loss: 1.9433 - accuracy: 0.2800 - precision: 0.4591 - recall: 0.0631 - val_loss: 2.0227 - val_accuracy: 0.2791 - val_precision: 0.5676 - val_recall: 0.0610 - lr: 0.0010
# Epoch 7/100
# 100/100 [==============================] - ETA: 0s - loss: 1.8332 - accuracy: 0.3325 - precision: 0.5105 - recall: 0.0912
# Epoch 7: val_loss did not improve from 2.02270
# 100/100 [==============================] - 6s 64ms/step - loss: 1.8332 - accuracy: 0.3325 - precision: 0.5105 - recall: 0.0912 - val_loss: 2.2923 - val_accuracy: 0.2297 - val_precision: 0.3023 - val_recall: 0.1134 - lr: 0.0010
# Epoch 8/100
# 100/100 [==============================] - ETA: 0s - loss: 1.7660 - accuracy: 0.3475 - precision: 0.5512 - recall: 0.1144
# Epoch 8: val_loss did not improve from 2.02270
# 100/100 [==============================] - 6s 65ms/step - loss: 1.7660 - accuracy: 0.3475 - precision: 0.5512 - recall: 0.1144 - val_loss: 2.0796 - val_accuracy: 0.2064 - val_precision: 0.3391 - val_recall: 0.1134 - lr: 0.0010
# Epoch 9/100
# 100/100 [==============================] - ETA: 0s - loss: 1.7383 - accuracy: 0.3619 - precision: 0.5978 - recall: 0.1375
# Epoch 9: val_loss improved from 2.02270 to 1.99202, saving model to best_emotion_model.h5
# 100/100 [==============================] - 6s 65ms/step - loss: 1.7383 - accuracy: 0.3619 - precision: 0.5978 - recall: 0.1375 - val_loss: 1.9920 - val_accuracy: 0.3227 - val_precision: 0.4926 - val_recall: 0.1948 - lr: 0.0010
# Epoch 10/100
# 100/100 [==============================] - ETA: 0s - loss: 1.6041 - accuracy: 0.4462 - precision: 0.6382 - recall: 0.1819
# Epoch 10: val_loss did not improve from 1.99202
# 100/100 [==============================] - 6s 64ms/step - loss: 1.6041 - accuracy: 0.4462 - precision: 0.6382 - recall: 0.1819 - val_loss: 2.0417 - val_accuracy: 0.2645 - val_precision: 0.3576 - val_recall: 0.1715 - lr: 0.0010
# Epoch 11/100
# 100/100 [==============================] - ETA: 0s - loss: 1.5739 - accuracy: 0.4363 - precision: 0.6488 - recall: 0.2044
# Epoch 11: val_loss did not improve from 1.99202
# 100/100 [==============================] - 6s 64ms/step - loss: 1.5739 - accuracy: 0.4363 - precision: 0.6488 - recall: 0.2044 - val_loss: 2.6523 - val_accuracy: 0.1773 - val_precision: 0.1897 - val_recall: 0.1076 - lr: 0.0010
# Epoch 12/100
# 100/100 [==============================] - ETA: 0s - loss: 1.5153 - accuracy: 0.4781 - precision: 0.6845 - recall: 0.2400
# Epoch 12: val_loss improved from 1.99202 to 1.74316, saving model to best_emotion_model.h5
# 100/100 [==============================] - 15s 150ms/step - loss: 1.5153 - accuracy: 0.4781 - precision: 0.6845 - recall: 0.2400 - val_loss: 1.7432 - val_accuracy: 0.3866 - val_precision: 0.5212 - val_recall: 0.2500 - lr: 0.0010
# Epoch 13/100
# 100/100 [==============================] - ETA: 0s - loss: 1.3870 - accuracy: 0.5206 - precision: 0.7123 - recall: 0.2862
# Epoch 13: val_loss improved from 1.74316 to 1.36968, saving model to best_emotion_model.h5
# 100/100 [==============================] - 16s 164ms/step - loss: 1.3870 - accuracy: 0.5206 - precision: 0.7123 - recall: 0.2862 - val_loss: 1.3697 - val_accuracy: 0.5349 - val_precision: 0.7301 - val_recall: 0.3459 - lr: 0.0010
# Epoch 14/100
# 100/100 [==============================] - ETA: 0s - loss: 1.2725 - accuracy: 0.5631 - precision: 0.7645 - recall: 0.3531
# Epoch 14: val_loss did not improve from 1.36968
# 100/100 [==============================] - 17s 171ms/step - loss: 1.2725 - accuracy: 0.5631 - precision: 0.7645 - recall: 0.3531 - val_loss: 1.8934 - val_accuracy: 0.3953 - val_precision: 0.5217 - val_recall: 0.2791 - lr: 0.0010
# Epoch 15/100
# 100/100 [==============================] - ETA: 0s - loss: 1.2399 - accuracy: 0.5825 - precision: 0.7527 - recall: 0.3937
# Epoch 15: val_loss did not improve from 1.36968
# 100/100 [==============================] - 12s 117ms/step - loss: 1.2399 - accuracy: 0.5825 - precision: 0.7527 - recall: 0.3937 - val_loss: 1.9764 - val_accuracy: 0.3721 - val_precision: 0.5542 - val_recall: 0.2674 - lr: 0.0010
# Epoch 16/100
# 100/100 [==============================] - ETA: 0s - loss: 1.1242 - accuracy: 0.6269 - precision: 0.7642 - recall: 0.4456
# Epoch 16: val_loss did not improve from 1.36968
# 100/100 [==============================] - 6s 64ms/step - loss: 1.1242 - accuracy: 0.6269 - precision: 0.7642 - recall: 0.4456 - val_loss: 1.6330 - val_accuracy: 0.3866 - val_precision: 0.5362 - val_recall: 0.2151 - lr: 0.0010
# Epoch 17/100
# 100/100 [==============================] - ETA: 0s - loss: 0.9631 - accuracy: 0.6912 - precision: 0.8266 - recall: 0.5394
# Epoch 17: val_loss did not improve from 1.36968
# 100/100 [==============================] - 6s 64ms/step - loss: 0.9631 - accuracy: 0.6912 - precision: 0.8266 - recall: 0.5394 - val_loss: 2.2232 - val_accuracy: 0.3983 - val_precision: 0.4198 - val_recall: 0.2965 - lr: 0.0010
# Epoch 18/100
# 100/100 [==============================] - ETA: 0s - loss: 0.9634 - accuracy: 0.7069 - precision: 0.8052 - recall: 0.5606
# Epoch 18: val_loss improved from 1.36968 to 1.33655, saving model to best_emotion_model.h5
# 100/100 [==============================] - 6s 63ms/step - loss: 0.9634 - accuracy: 0.7069 - precision: 0.8052 - recall: 0.5606 - val_loss: 1.3366 - val_accuracy: 0.5756 - val_precision: 0.6550 - val_recall: 0.4913 - lr: 0.0010
# Epoch 19/100
# 100/100 [==============================] - ETA: 0s - loss: 0.8678 - accuracy: 0.7250 - precision: 0.8364 - recall: 0.6169
# Epoch 19: val_loss improved from 1.33655 to 1.20449, saving model to best_emotion_model.h5
# 100/100 [==============================] - 6s 64ms/step - loss: 0.8678 - accuracy: 0.7250 - precision: 0.8364 - recall: 0.6169 - val_loss: 1.2045 - val_accuracy: 0.5843 - val_precision: 0.6827 - val_recall: 0.4942 - lr: 0.0010
# Epoch 20/100
# 100/100 [==============================] - ETA: 0s - loss: 0.7762 - accuracy: 0.7694 - precision: 0.8490 - recall: 0.6675
# Epoch 20: val_loss improved from 1.20449 to 1.12045, saving model to best_emotion_model.h5
# 100/100 [==============================] - 6s 64ms/step - loss: 0.7762 - accuracy: 0.7694 - precision: 0.8490 - recall: 0.6675 - val_loss: 1.1204 - val_accuracy: 0.6657 - val_precision: 0.7537 - val_recall: 0.5959 - lr: 0.0010
# Epoch 21/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6539 - accuracy: 0.8131 - precision: 0.8879 - recall: 0.7325
# Epoch 21: val_loss improved from 1.12045 to 0.95116, saving model to best_emotion_model.h5
# 100/100 [==============================] - 6s 64ms/step - loss: 0.6539 - accuracy: 0.8131 - precision: 0.8879 - recall: 0.7325 - val_loss: 0.9512 - val_accuracy: 0.7064 - val_precision: 0.7759 - val_recall: 0.6541 - lr: 0.0010
# Epoch 22/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6810 - accuracy: 0.7925 - precision: 0.8484 - recall: 0.7237
# Epoch 22: val_loss did not improve from 0.95116
# 100/100 [==============================] - 6s 63ms/step - loss: 0.6810 - accuracy: 0.7925 - precision: 0.8484 - recall: 0.7237 - val_loss: 1.9775 - val_accuracy: 0.4215 - val_precision: 0.4688 - val_recall: 0.3924 - lr: 0.0010
# Epoch 23/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6013 - accuracy: 0.8338 - precision: 0.8948 - recall: 0.7763
# Epoch 23: val_loss improved from 0.95116 to 0.92257, saving model to best_emotion_model.h5
# 100/100 [==============================] - 6s 64ms/step - loss: 0.6013 - accuracy: 0.8338 - precision: 0.8948 - recall: 0.7763 - val_loss: 0.9226 - val_accuracy: 0.7209 - val_precision: 0.7700 - val_recall: 0.6715 - lr: 0.0010
# Epoch 24/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4610 - accuracy: 0.8794 - precision: 0.9216 - recall: 0.8444
# Epoch 24: val_loss did not improve from 0.92257
# 100/100 [==============================] - 6s 63ms/step - loss: 0.4610 - accuracy: 0.8794 - precision: 0.9216 - recall: 0.8444 - val_loss: 1.2799 - val_accuracy: 0.6657 - val_precision: 0.6990 - val_recall: 0.6279 - lr: 0.0010
# Epoch 25/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4246 - accuracy: 0.8975 - precision: 0.9207 - recall: 0.8706
# Epoch 25: val_loss did not improve from 0.92257
# 100/100 [==============================] - 6s 63ms/step - loss: 0.4246 - accuracy: 0.8975 - precision: 0.9207 - recall: 0.8706 - val_loss: 1.0894 - val_accuracy: 0.6686 - val_precision: 0.6969 - val_recall: 0.6483 - lr: 0.0010
# Epoch 26/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4085 - accuracy: 0.8981 - precision: 0.9215 - recall: 0.8725
# Epoch 26: val_loss did not improve from 0.92257
# 100/100 [==============================] - 6s 64ms/step - loss: 0.4085 - accuracy: 0.8981 - precision: 0.9215 - recall: 0.8725 - val_loss: 1.3696 - val_accuracy: 0.6599 - val_precision: 0.6897 - val_recall: 0.6395 - lr: 0.0010
# Epoch 27/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4038 - accuracy: 0.9031 - precision: 0.9238 - recall: 0.8869
# Epoch 27: val_loss improved from 0.92257 to 0.83776, saving model to best_emotion_model.h5
# 100/100 [==============================] - 6s 65ms/step - loss: 0.4038 - accuracy: 0.9031 - precision: 0.9238 - recall: 0.8869 - val_loss: 0.8378 - val_accuracy: 0.7878 - val_precision: 0.8050 - val_recall: 0.7442 - lr: 0.0010
# Epoch 28/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2924 - accuracy: 0.9362 - precision: 0.9510 - recall: 0.9225
# Epoch 28: val_loss did not improve from 0.83776
# 100/100 [==============================] - 6s 64ms/step - loss: 0.2924 - accuracy: 0.9362 - precision: 0.9510 - recall: 0.9225 - val_loss: 1.1499 - val_accuracy: 0.6919 - val_precision: 0.7389 - val_recall: 0.6744 - lr: 0.0010
# Epoch 29/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2907 - accuracy: 0.9294 - precision: 0.9479 - recall: 0.9206
# Epoch 29: val_loss did not improve from 0.83776
# 100/100 [==============================] - 6s 64ms/step - loss: 0.2907 - accuracy: 0.9294 - precision: 0.9479 - recall: 0.9206 - val_loss: 0.8985 - val_accuracy: 0.7849 - val_precision: 0.8006 - val_recall: 0.7703 - lr: 0.0010
# Epoch 30/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2196 - accuracy: 0.9606 - precision: 0.9683 - recall: 0.9550
# Epoch 30: val_loss improved from 0.83776 to 0.63423, saving model to best_emotion_model.h5
# 100/100 [==============================] - 6s 65ms/step - loss: 0.2196 - accuracy: 0.9606 - precision: 0.9683 - recall: 0.9550 - val_loss: 0.6342 - val_accuracy: 0.8547 - val_precision: 0.8690 - val_recall: 0.8488 - lr: 0.0010
# Epoch 31/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2457 - accuracy: 0.9494 - precision: 0.9544 - recall: 0.9419
# Epoch 31: val_loss did not improve from 0.63423
# 100/100 [==============================] - 6s 64ms/step - loss: 0.2457 - accuracy: 0.9494 - precision: 0.9544 - recall: 0.9419 - val_loss: 0.7945 - val_accuracy: 0.8198 - val_precision: 0.8415 - val_recall: 0.8023 - lr: 0.0010
# Epoch 32/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2744 - accuracy: 0.9412 - precision: 0.9492 - recall: 0.9337
# Epoch 32: val_loss did not improve from 0.63423
# 100/100 [==============================] - 6s 64ms/step - loss: 0.2744 - accuracy: 0.9412 - precision: 0.9492 - recall: 0.9337 - val_loss: 0.9096 - val_accuracy: 0.7762 - val_precision: 0.7964 - val_recall: 0.7733 - lr: 0.0010
# Epoch 33/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2380 - accuracy: 0.9525 - precision: 0.9643 - recall: 0.9450
# Epoch 33: val_loss did not improve from 0.63423
# 100/100 [==============================] - 6s 64ms/step - loss: 0.2380 - accuracy: 0.9525 - precision: 0.9643 - recall: 0.9450 - val_loss: 1.7767 - val_accuracy: 0.6279 - val_precision: 0.6399 - val_recall: 0.6250 - lr: 0.0010
# Epoch 34/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2597 - accuracy: 0.9450 - precision: 0.9576 - recall: 0.9325
# Epoch 34: val_loss did not improve from 0.63423
# 100/100 [==============================] - 6s 64ms/step - loss: 0.2597 - accuracy: 0.9450 - precision: 0.9576 - recall: 0.9325 - val_loss: 0.9319 - val_accuracy: 0.7703 - val_precision: 0.8000 - val_recall: 0.7558 - lr: 0.0010
# Epoch 35/100
# 100/100 [==============================] - ETA: 0s - loss: 0.1880 - accuracy: 0.9675 - precision: 0.9747 - recall: 0.9631
# Epoch 35: val_loss did not improve from 0.63423
# 100/100 [==============================] - 7s 71ms/step - loss: 0.1880 - accuracy: 0.9675 - precision: 0.9747 - recall: 0.9631 - val_loss: 1.0891 - val_accuracy: 0.7587 - val_precision: 0.7818 - val_recall: 0.7500 - lr: 0.0010
# Epoch 36/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2032 - accuracy: 0.9663 - precision: 0.9722 - recall: 0.9619
# Epoch 36: val_loss did not improve from 0.63423
# 100/100 [==============================] - 6s 64ms/step - loss: 0.2032 - accuracy: 0.9663 - precision: 0.9722 - recall: 0.9619 - val_loss: 1.0802 - val_accuracy: 0.7733 - val_precision: 0.7922 - val_recall: 0.7645 - lr: 0.0010
# Epoch 37/100
# 100/100 [==============================] - ETA: 0s - loss: 0.1915 - accuracy: 0.9631 - precision: 0.9709 - recall: 0.9587
# Epoch 37: val_loss did not improve from 0.63423
# 100/100 [==============================] - 7s 68ms/step - loss: 0.1915 - accuracy: 0.9631 - precision: 0.9709 - recall: 0.9587 - val_loss: 1.3146 - val_accuracy: 0.7413 - val_precision: 0.7560 - val_recall: 0.7297 - lr: 0.0010
# Epoch 38/100
# 100/100 [==============================] - ETA: 0s - loss: 0.1796 - accuracy: 0.9706 - precision: 0.9723 - recall: 0.9669
# Epoch 38: val_loss did not improve from 0.63423
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1796 - accuracy: 0.9706 - precision: 0.9723 - recall: 0.9669 - val_loss: 0.9001 - val_accuracy: 0.8023 - val_precision: 0.8185 - val_recall: 0.7994 - lr: 0.0010
# Epoch 39/100
# 100/100 [==============================] - ETA: 0s - loss: 0.1890 - accuracy: 0.9681 - precision: 0.9722 - recall: 0.9613
# Epoch 39: val_loss did not improve from 0.63423
# 100/100 [==============================] - 6s 63ms/step - loss: 0.1890 - accuracy: 0.9681 - precision: 0.9722 - recall: 0.9613 - val_loss: 1.3387 - val_accuracy: 0.7209 - val_precision: 0.7409 - val_recall: 0.7064 - lr: 0.0010
# Epoch 40/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2324 - accuracy: 0.9556 - precision: 0.9607 - recall: 0.9462
# Epoch 40: val_loss did not improve from 0.63423
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 100/100 [==============================] - 6s 64ms/step - loss: 0.2324 - accuracy: 0.9556 - precision: 0.9607 - recall: 0.9462 - val_loss: 1.0083 - val_accuracy: 0.7936 - val_precision: 0.8024 - val_recall: 0.7907 - lr: 0.0010
# Epoch 41/100
# 100/100 [==============================] - ETA: 0s - loss: 0.1584 - accuracy: 0.9775 - precision: 0.9780 - recall: 0.9737
# Epoch 41: val_loss did not improve from 0.63423
# 100/100 [==============================] - 6s 62ms/step - loss: 0.1584 - accuracy: 0.9775 - precision: 0.9780 - recall: 0.9737 - val_loss: 0.9027 - val_accuracy: 0.8023 - val_precision: 0.8077 - val_recall: 0.7936 - lr: 5.0000e-04
# Epoch 42/100
# 100/100 [==============================] - ETA: 0s - loss: 0.1286 - accuracy: 0.9869 - precision: 0.9887 - recall: 0.9856
# Epoch 42: val_loss did not improve from 0.63423
# 100/100 [==============================] - 6s 62ms/step - loss: 0.1286 - accuracy: 0.9869 - precision: 0.9887 - recall: 0.9856 - val_loss: 0.9048 - val_accuracy: 0.8227 - val_precision: 0.8294 - val_recall: 0.8198 - lr: 5.0000e-04
# Epoch 43/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0999 - accuracy: 0.9969 - precision: 0.9975 - recall: 0.9956
# Epoch 43: val_loss did not improve from 0.63423
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0999 - accuracy: 0.9969 - precision: 0.9975 - recall: 0.9956 - val_loss: 0.8103 - val_accuracy: 0.8459 - val_precision: 0.8605 - val_recall: 0.8430 - lr: 5.0000e-04
# Epoch 44/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0983 - accuracy: 0.9919 - precision: 0.9950 - recall: 0.9912
# Epoch 44: val_loss did not improve from 0.63423
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0983 - accuracy: 0.9919 - precision: 0.9950 - recall: 0.9912 - val_loss: 0.8246 - val_accuracy: 0.8576 - val_precision: 0.8614 - val_recall: 0.8488 - lr: 5.0000e-04
# Epoch 45/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0901 - accuracy: 0.9981 - precision: 0.9987 - recall: 0.9975
# Epoch 45: val_loss did not improve from 0.63423
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0901 - accuracy: 0.9981 - precision: 0.9987 - recall: 0.9975 - val_loss: 0.8205 - val_accuracy: 0.8547 - val_precision: 0.8609 - val_recall: 0.8459 - lr: 5.0000e-04
# Epoch 46/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0940 - accuracy: 0.9944 - precision: 0.9962 - recall: 0.9937
# Epoch 46: val_loss did not improve from 0.63423
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0940 - accuracy: 0.9944 - precision: 0.9962 - recall: 0.9937 - val_loss: 0.7962 - val_accuracy: 0.8488 - val_precision: 0.8538 - val_recall: 0.8488 - lr: 5.0000e-04
# Epoch 47/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0793 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 47: val_loss did not improve from 0.63423
# 100/100 [==============================] - 6s 64ms/step - loss: 0.0793 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7968 - val_accuracy: 0.8547 - val_precision: 0.8622 - val_recall: 0.8547 - lr: 5.0000e-04
# Epoch 48/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0771 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9987
# Epoch 48: val_loss did not improve from 0.63423
# 100/100 [==============================] - 6s 64ms/step - loss: 0.0771 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9987 - val_loss: 0.8227 - val_accuracy: 0.8517 - val_precision: 0.8542 - val_recall: 0.8517 - lr: 5.0000e-04
# Epoch 49/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0806 - accuracy: 0.9981 - precision: 0.9987 - recall: 0.9969
# Epoch 49: val_loss did not improve from 0.63423
# 100/100 [==============================] - 6s 64ms/step - loss: 0.0806 - accuracy: 0.9981 - precision: 0.9987 - recall: 0.9969 - val_loss: 0.8661 - val_accuracy: 0.8488 - val_precision: 0.8538 - val_recall: 0.8488 - lr: 5.0000e-04
# Epoch 50/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0799 - accuracy: 0.9981 - precision: 0.9981 - recall: 0.9975Restoring model weights from the end of the best epoch: 30.
#
# Epoch 50: val_loss did not improve from 0.63423
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 100/100 [==============================] - 6s 64ms/step - loss: 0.0799 - accuracy: 0.9981 - precision: 0.9981 - recall: 0.9975 - val_loss: 0.8210 - val_accuracy: 0.8576 - val_precision: 0.8651 - val_recall: 0.8576 - lr: 5.0000e-04
# Epoch 50: early stopping
# 11/11 [==============================] - 0s 14ms/step - loss: 0.9536 - accuracy: 0.7849 - precision: 0.7982 - recall: 0.7703
# Test Loss: 0.9536
# Test Accuracy: 0.7849
# Test Precision: 0.7982
# Test Recall: 0.7703
# 11/11 [==============================] - 0s 11ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.82      0.89      0.85        46
#         calm       0.82      0.84      0.83        49
#      disgust       0.89      0.75      0.81        44
#      fearful       0.82      0.78      0.80        46
#        happy       0.66      0.61      0.64        44
#      neutral       0.52      0.71      0.60        24
#          sad       0.79      0.73      0.76        45
#    surprised       0.89      0.91      0.90        46
#
#     accuracy                           0.78       344
#    macro avg       0.78      0.78      0.77       344
# weighted avg       0.79      0.78      0.79       344
